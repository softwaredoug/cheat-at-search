# %% [markdown]
# # Classic RAG
#
# Using the Wayfair dataset, this shows the 'single shot' classic RAG
#
# We do exactly one search, retrieve results for the agent, and ask the agent to incorporate them in answering the user's question.

# %%
# !pip install git+https://github.com/softwaredoug/cheat-at-search.git
from cheat_at_search.data_dir import mount
mount(use_gdrive=True)    # colab, share data across notebook runs on gdrive
# mount(use_gdrive=False) # <- colab without gdrive
# mount(use_gdrive=False, manual_path="/path/to/directory")  # <- force data path to specific directory, ie you're running locally.
# Out:
# Collecting git+https://github.com/softwaredoug/cheat-at-search.git
#   Cloning https://github.com/softwaredoug/cheat-at-search.git to /tmp/pip-req-build-yo78rvhk
#   Running command git clone --filter=blob:none --quiet https://github.com/softwaredoug/cheat-at-search.git /tmp/pip-req-build-yo78rvhk
#   Resolved https://github.com/softwaredoug/cheat-at-search.git to commit 6a08d097f1d6eaa068fb61af47c621df1682f5e2
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: google-genai<2.0.0,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from cheat_at_search==0.1.0) (1.60.0)
# Requirement already satisfied: lxml<7.0.0,>=6.0.2 in /usr/local/lib/python3.12/dist-packages (from cheat_at_search==0.1.0) (6.0.2)
# Collecting openai<2.0.0,>=1.84.0 (from cheat_at_search==0.1.0)
#   Downloading openai-1.109.1-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: pandas<3.0.0,>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from cheat_at_search==0.1.0) (2.2.2)
# Requirement already satisfied: pyarrow<22.0.0,>=14.0.0 in /usr/local/lib/python3.12/dist-packages (from cheat_at_search==0.1.0) (18.1.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.11.0 in /usr/local/lib/python3.12/dist-packages (from cheat_at_search==0.1.0) (2.12.3)
# Collecting pystemmer<4.0.0,>=3.0.0 (from cheat_at_search==0.1.0)
#   Downloading PyStemmer-3.0.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Requirement already satisfied: pyyaml<7.0.0,>=6.0.3 in /usr/local/lib/python3.12/dist-packages (from cheat_at_search==0.1.0) (6.0.3)
# Collecting searcharray<0.0.74,>=0.0.73 (from cheat_at_search==0.1.0)
#   Downloading searcharray-0.0.73-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (4.12.1)
# Requirement already satisfied: google-auth<3.0.0,>=2.47.0 in /usr/local/lib/python3.12/dist-packages (from google-auth[requests]<3.0.0,>=2.47.0->google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (2.47.0)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (0.28.1)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (2.32.4)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (9.1.2)
# Requirement already satisfied: websockets<15.1.0,>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (15.0.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.11.0 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (4.15.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (1.9.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (1.3.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from openai<2.0.0,>=1.84.0->cheat_at_search==0.1.0) (0.12.0)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.12/dist-packages (from openai<2.0.0,>=1.84.0->cheat_at_search==0.1.0) (4.67.1)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0.0,>=2.2.0->cheat_at_search==0.1.0) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0.0,>=2.2.0->cheat_at_search==0.1.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0.0,>=2.2.0->cheat_at_search==0.1.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0.0,>=2.2.0->cheat_at_search==0.1.0) (2025.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.11.0->cheat_at_search==0.1.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.11.0->cheat_at_search==0.1.0) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.11.0->cheat_at_search==0.1.0) (0.4.2)
# Requirement already satisfied: Cython in /usr/local/lib/python3.12/dist-packages (from searcharray<0.0.74,>=0.0.73->cheat_at_search==0.1.0) (3.0.12)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5.0.0,>=4.8.0->google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (3.11)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (4.9.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (0.16.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas<3.0.0,>=2.2.0->cheat_at_search==0.1.0) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.28.1->google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.28.1->google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (2.5.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (0.6.2)
# Downloading openai-1.109.1-py3-none-any.whl (948 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 948.6/948.6 kB 14.5 MB/s eta 0:00:00
# Downloading PyStemmer-3.0.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (745 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 745.3/745.3 kB 29.3 MB/s eta 0:00:00
# Downloading searcharray-0.0.73-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 11.7 MB/s eta 0:00:00
# Building wheels for collected packages: cheat_at_search
#   Building wheel for cheat_at_search (pyproject.toml) ... done
#   Created wheel for cheat_at_search: filename=cheat_at_search-0.1.0-py3-none-any.whl size=64150 sha256=bc2e8078e2fc527fcee519d231d6892564a6d1a5550dd365aeeeb97aaeeb0211
#   Stored in directory: /tmp/pip-ephem-wheel-cache-whhk2w_7/wheels/ea/96/d3/e69453e5f86e6f891864e5b5baf2b11ffda2d0981d9f8a138e
# Successfully built cheat_at_search
# Installing collected packages: pystemmer, searcharray, openai, cheat_at_search
#   Attempting uninstall: openai
#     Found existing installation: openai 2.16.0
#     Uninstalling openai-2.16.0:
#       Successfully uninstalled openai-2.16.0
# Successfully installed cheat_at_search-0.1.0 openai-1.109.1 pystemmer-3.0.0 searcharray-0.0.73
# Mounted at /content/drive

# %% [markdown]
# ## Get an OpenAI Key
#
# This will prompt you for an OpenAI Key to interact with GPT-5

# %%
from cheat_at_search.data_dir import key_for_provider
from openai import OpenAI

OPENAI_KEY = key_for_provider("openai")

openai = OpenAI(api_key=OPENAI_KEY)

# %% [markdown]
# ## Load the Wayfair corpus
#
# We'll recommend products only from this corpus

# %%
from cheat_at_search.wands_data import corpus

corpus['category'] = corpus['category'].str.strip()

corpus
# Out:
#        product_id                                       product_name  \
# 0               0                            solid wood platform bed
# 1               1                        all-clad 7 qt . slow cooker
# 2               2            all-clad electrics 6.5 qt . slow cooker
# 3               3       all-clad all professional tools pizza cutter
# 4               4  baldwin prestige alcott passage knob with roun...
# ...           ...                                                ...
# 42989       42989  malibu pressure balanced diverter fixed shower...
# 42990       42990              emmeline 5 piece breakfast dining set
# 42991       42991                      maloney 3 piece pub table set
# 42992       42992           fletcher 27.5 '' wide polyester armchair
# 42993       42993                            griffin 29 '' bar stool
#
#                              product_class  \
# 0                                     Beds
# 1                             Slow Cookers
# 2                             Slow Cookers
# 3             Slicers, Peelers And Graters
# 4                               Door Knobs
# ...                                    ...
# 42989                        Shower Panels
# 42990                    Dining Table Sets
# 42991                    Dining Table Sets
# 42992  Teen Lounge Furniture|Accent Chairs
# 42993                           Bar Stools
#
#                                       category hierarchy  \
# 0      Furniture / Bedroom Furniture / Beds & Headboa...
# 1      Kitchen & Tabletop / Small Kitchen Appliances ...
# 2      Kitchen & Tabletop / Small Kitchen Appliances ...
# 3                             Browse By Brand / All-Clad
# 4      Home Improvement / Doors & Door Hardware / Doo...
# ...                                                  ...
# 42989  Home Improvement / Bathroom Remodel & Bathroom...
# 42990  Furniture / Kitchen & Dining Furniture / Dinin...
# 42991  Furniture / Kitchen & Dining Furniture / Dinin...
# 42992  Furniture / Living Room Furniture / Chairs & S...
# 42993  Furniture / Kitchen & Dining Furniture / Bar F...
#
#                                      product_description  \
# 0      good , deep sleep can be quite difficult to ha...
# 1      create delicious slow-cooked meals , from tend...
# 2      prepare home-cooked meals on any schedule with...
# 3      this original stainless tool was designed to c...
# 4      the hardware has a rich heritage of delivering...
# ...                                                  ...
# 42989  the malibu pressure balanced diverter fixed sh...
# 42990
# 42991  this pub table set includes 1 counter height t...
# 42992  bring iconic , modern style to your space in a...
# 42993  this set of two barstools features a minimalis...
#
#                                         product_features  rating_count  \
# 0      overallwidth-sidetoside:64.7|dsprimaryproducts...          15.0
# 1      capacityquarts:7|producttype : slow cooker|pro...         100.0
# 2      features : keep warm setting|capacityquarts:6....         208.0
# 3      overallwidth-sidetoside:3.5|warrantylength : l...          69.0
# 4      compatibledoorthickness:1.375 '' |countryofori...          70.0
# ...                                                  ...           ...
# 42989  producttype : shower panel|spraypattern : rain...           3.0
# 42990  basematerialdetails : steel| : gray wood|ofhar...        1314.0
# 42991  additionaltoolsrequirednotincluded : power dri...          49.0
# 42992  legmaterialdetails : rubberwood|backheight-sea...        1746.0
# 42993  distancebetweenfloorandfootrest:7.5|dssecondar...          20.0
#
#        average_rating  review_count  \
# 0                 4.5          15.0
# 1                 2.0          98.0
# 2                 3.0         181.0
# 3                 4.5          42.0
# 4                 5.0          42.0
# ...               ...           ...
# 42989             4.5           2.0
# 42990             4.5         864.0
# 42991             4.0          41.0
# 42992             4.5        1226.0
# 42993             4.5          20.0
#
#                                                 features  doc_id  \
# 0      [overallwidth-sidetoside:64.7, dsprimaryproduc...       0
# 1      [capacityquarts:7, producttype : slow cooker, ...       1
# 2      [features : keep warm setting, capacityquarts:...       2
# 3      [overallwidth-sidetoside:3.5, warrantylength :...       3
# 4      [compatibledoorthickness:1.375 '' , countryofo...       4
# ...                                                  ...     ...
# 42989  [producttype : shower panel, spraypattern : ra...   42989
# 42990  [basematerialdetails : steel,  : gray wood, of...   42990
# 42991  [additionaltoolsrequirednotincluded : power dr...   42991
# 42992  [legmaterialdetails : rubberwood, backheight-s...   42992
# 42993  [distancebetweenfloorandfootrest:7.5, dssecond...   42993
#
#                                                    title  \
# 0                                solid wood platform bed
# 1                            all-clad 7 qt . slow cooker
# 2                all-clad electrics 6.5 qt . slow cooker
# 3           all-clad all professional tools pizza cutter
# 4      baldwin prestige alcott passage knob with roun...
# ...                                                  ...
# 42989  malibu pressure balanced diverter fixed shower...
# 42990              emmeline 5 piece breakfast dining set
# 42991                      maloney 3 piece pub table set
# 42992           fletcher 27.5 '' wide polyester armchair
# 42993                            griffin 29 '' bar stool
#
#                                              description            category  \
# 0      good , deep sleep can be quite difficult to ha...           Furniture
# 1      create delicious slow-cooked meals , from tend...  Kitchen & Tabletop
# 2      prepare home-cooked meals on any schedule with...  Kitchen & Tabletop
# 3      this original stainless tool was designed to c...     Browse By Brand
# 4      the hardware has a rich heritage of delivering...    Home Improvement
# ...                                                  ...                 ...
# 42989  the malibu pressure balanced diverter fixed sh...    Home Improvement
# 42990                                                              Furniture
# 42991  this pub table set includes 1 counter height t...           Furniture
# 42992  bring iconic , modern style to your space in a...           Furniture
# 42993  this set of two barstools features a minimalis...           Furniture
#
#                                  sub_category  \
# 0                          Bedroom Furniture
# 1                   Small Kitchen Appliances
# 2                   Small Kitchen Appliances
# 3                                    All-Clad
# 4                      Doors & Door Hardware
# ...                                       ...
# 42989   Bathroom Remodel & Bathroom Fixtures
# 42990             Kitchen & Dining Furniture
# 42991             Kitchen & Dining Furniture
# 42992                  Living Room Furniture
# 42993             Kitchen & Dining Furniture
#
#                                               cat_subcat  \
# 0                       Furniture  /  Bedroom Furniture
# 1       Kitchen & Tabletop  /  Small Kitchen Appliances
# 2       Kitchen & Tabletop  /  Small Kitchen Appliances
# 3                           Browse By Brand  /  All-Clad
# 4            Home Improvement  /  Doors & Door Hardware
# ...                                                  ...
# 42989  Home Improvement  /  Bathroom Remodel & Bathro...
# 42990          Furniture  /  Kitchen & Dining Furniture
# 42991          Furniture  /  Kitchen & Dining Furniture
# 42992               Furniture  /  Living Room Furniture
# 42993          Furniture  /  Kitchen & Dining Furniture
#
#                                           title_snowball  \
# 0            Terms({'solid', 'platform', 'bed', 'wood'})
# 1      Terms({'cooker', 'clad', 'all', 'qt', 'slow', ...
# 2      Terms({'cooker', 'clad', 'all', 'qt', '6', '5'...
# 3      Terms({'pizza', 'clad', 'all', 'profession', '...
# 4      Terms({'baldwin', 'rosett', 'with', 'round', '...
# ...                                                  ...
# 42989  Terms({'divert', 'pressur', 'head', 'panel', '...
# 42990  Terms({'piec', 'set', 'breakfast', 'dine', '5'...
# 42991  Terms({'piec', 'set', 'tabl', '3', 'pub', 'mal...
# 42992  Terms({'fletcher', 'polyest', '5', 'wide', 'ar...
# 42993           Terms({'griffin', 'bar', 'stool', '29'})
#
#                                     description_snowball
# 0      Terms({'type', 'well', 'problem', 'our', 'emph...
# 1      Terms({'entertain', 'ingredi', 'come', 'meal',...
# 2      Terms({'cooker', 'hour', 'insert', 'slow', 'me...
# 3      Terms({'rotari', 'through', 'pasta', 'easili',...
# 4      Terms({'baldwin', 'rosett', 'is', 'someon', 'p...
# ...                                                  ...
# 42989  Terms({'head', 'is', 'overs', 'easili', 'the',...
# 42990                                       Terms(set())
# 42991  Terms({'entertain', 'as', 'set', 'make', 'coff...
# 42992  Terms({'support', 'upholsteri', 'taper', 'stai...
# 42993  Terms({'lean', 'entertain', 'coffe', 'doubl', ...
#
# [42994 rows x 18 columns]

# %% [markdown]
# ### Index the furniture
#
# We'll index title and description with basic stemming to be able to retrieve them

# %%
from searcharray import SearchArray
from cheat_at_search.tokenizers import snowball_tokenizer

corpus['title_snowball'] = SearchArray.index(corpus['title'].fillna(''), snowball_tokenizer)
corpus['description_snowball'] = SearchArray.index(corpus['description'].fillna(''), snowball_tokenizer)
# Out:
# 2026-02-03 14:53:58,925 - searcharray.indexing - INFO - Indexing begins w/ 4 workers
# INFO:searcharray.indexing:Indexing begins w/ 4 workers
# 2026-02-03 14:53:58,944 - searcharray.indexing - INFO - 0 Batch Start tokenization
# INFO:searcharray.indexing:0 Batch Start tokenization
# 2026-02-03 14:53:58,951 - searcharray.indexing - INFO - Tokenizing 42994 documents
# INFO:searcharray.indexing:Tokenizing 42994 documents
# 2026-02-03 14:53:59,575 - searcharray.indexing - INFO - Tokenized 10000 (23.259059403637718%)
# INFO:searcharray.indexing:Tokenized 10000 (23.259059403637718%)
# 2026-02-03 14:54:00,116 - searcharray.indexing - INFO - Tokenized 20000 (46.518118807275435%)
# INFO:searcharray.indexing:Tokenized 20000 (46.518118807275435%)
# 2026-02-03 14:54:00,739 - searcharray.indexing - INFO - Tokenized 30000 (69.77717821091315%)
# INFO:searcharray.indexing:Tokenized 30000 (69.77717821091315%)
# 2026-02-03 14:54:01,138 - searcharray.indexing - INFO - Tokenized 40000 (93.03623761455087%)
# INFO:searcharray.indexing:Tokenized 40000 (93.03623761455087%)
# 2026-02-03 14:54:01,472 - searcharray.indexing - INFO - Tokenization -- vstacking
# INFO:searcharray.indexing:Tokenization -- vstacking
# 2026-02-03 14:54:01,489 - searcharray.indexing - INFO - Tokenization -- DONE
# INFO:searcharray.indexing:Tokenization -- DONE
# 2026-02-03 14:54:01,508 - searcharray.indexing - INFO - Inverting docs->terms
# INFO:searcharray.indexing:Inverting docs->terms
# 2026-02-03 14:54:01,604 - searcharray.indexing - INFO - Encoding positions to bit array
# INFO:searcharray.indexing:Encoding positions to bit array
# 2026-02-03 14:54:01,691 - searcharray.indexing - INFO - Batch tokenization complete
# INFO:searcharray.indexing:Batch tokenization complete
# 2026-02-03 14:54:01,699 - searcharray.indexing - INFO - (main thread) Processing 1 batch results
# INFO:searcharray.indexing:(main thread) Processing 1 batch results
# 2026-02-03 14:54:01,790 - searcharray.indexing - INFO - Indexing from tokenization complete
# INFO:searcharray.indexing:Indexing from tokenization complete
# 2026-02-03 14:54:01,849 - searcharray.indexing - INFO - Indexing begins w/ 4 workers
# INFO:searcharray.indexing:Indexing begins w/ 4 workers
# 2026-02-03 14:54:01,869 - searcharray.indexing - INFO - 0 Batch Start tokenization
# INFO:searcharray.indexing:0 Batch Start tokenization
# 2026-02-03 14:54:01,871 - searcharray.indexing - INFO - Tokenizing 42994 documents
# INFO:searcharray.indexing:Tokenizing 42994 documents
# 2026-02-03 14:54:03,801 - searcharray.indexing - INFO - Tokenized 10000 (23.259059403637718%)
# INFO:searcharray.indexing:Tokenized 10000 (23.259059403637718%)
# 2026-02-03 14:54:05,626 - searcharray.indexing - INFO - Tokenized 20000 (46.518118807275435%)
# INFO:searcharray.indexing:Tokenized 20000 (46.518118807275435%)
# 2026-02-03 14:54:10,061 - searcharray.indexing - INFO - Tokenized 30000 (69.77717821091315%)
# INFO:searcharray.indexing:Tokenized 30000 (69.77717821091315%)
# 2026-02-03 14:54:15,403 - searcharray.indexing - INFO - Tokenized 40000 (93.03623761455087%)
# INFO:searcharray.indexing:Tokenized 40000 (93.03623761455087%)
# 2026-02-03 14:54:16,240 - searcharray.indexing - INFO - Tokenization -- vstacking
# INFO:searcharray.indexing:Tokenization -- vstacking
# 2026-02-03 14:54:16,350 - searcharray.indexing - INFO - Tokenization -- DONE
# INFO:searcharray.indexing:Tokenization -- DONE
# 2026-02-03 14:54:16,384 - searcharray.indexing - INFO - Inverting docs->terms
# INFO:searcharray.indexing:Inverting docs->terms
# 2026-02-03 14:54:17,158 - searcharray.indexing - INFO - Encoding positions to bit array
# INFO:searcharray.indexing:Encoding positions to bit array
# 2026-02-03 14:54:17,434 - searcharray.indexing - INFO - Batch tokenization complete
# INFO:searcharray.indexing:Batch tokenization complete
# 2026-02-03 14:54:17,437 - searcharray.indexing - INFO - (main thread) Processing 1 batch results
# INFO:searcharray.indexing:(main thread) Processing 1 batch results
# 2026-02-03 14:54:17,656 - searcharray.indexing - INFO - Indexing from tokenization complete
# INFO:searcharray.indexing:Indexing from tokenization complete

# %% [markdown]
# ## Create a furniture products search function
#
# Here is a function that searches a Wayfair product dataset. It's just a Python function that returns top 10 pieces of furniture.
#
# Right now we'll call it directly, soon we'll help ChatGPT interact with this.

# %%
import numpy as np
from typing import Union

def search_furniture(keywords: str) -> list[dict[str, Union[str, int, float]]]:
    """Search the available furniture products, get top 10 furniture.

    This is just a naive BM25 / keyword search of the product title and description.
    Don't expect sophisticated synonyms or semantic search. Just basic keyword with
    some stemming.

    """
    print("search", keywords)
    required_keywords = [term[1:] for term in keywords.split() if term.startswith("+")]
    bm25_scores = np.zeros(len(corpus))
    for term in snowball_tokenizer(keywords):
        bm25_scores += corpus['title_snowball'].array.score(term) * 7
        bm25_scores += corpus['description_snowball'].array.score(term) * 4

    for required_term in snowball_tokenizer(" ".join(required_keywords)):
        required_score = (corpus['title_snowball'].array.score(required_term) +
                          corpus['description_snowball'].array.score(required_term))
        bm25_scores[required_score == 0] = 0

    top_k_indices = np.argsort(bm25_scores)[-10:][::-1]
    bm25_scores = bm25_scores[top_k_indices]
    top_movies = corpus.iloc[top_k_indices].copy()
    top_movies.loc[:, 'score'] = bm25_scores

    results = []
    for id, row in top_movies.iterrows():
        results.append({
            'id': row['doc_id'],
            'title': row['title'],
            'description': row['description'],
            'score': row['score']
        })
    return results



search_furniture("geometric style +couch")
# Out:
# search geometric style +couch
# [{'id': 1217,
#   'title': 'extra large and wide couch riser',
#   'description': 'our largest and oversized couch , furniture , and bed riser . made for those extra-large couch and furniture legs . we created these to allow one time stacking . tested to lift over 6,000 pounds - we made it heavy duty . includes a leather pad to keep legs from sliding off the top and a rubber base to prevent slipping on the floor . fits almost all sofas , couches , beds , large legs , and feet .',
#   'score': 37.797197341918945},
#  {'id': 25326,
#   'title': 'pixar cars 2 in 1 flip open kids foam couch',
#   'description': "now your little one can have their very own place to sit with the marshmallow furniture children 's 2-in-1 flip open foam kids sofa . this couch for toddlers is the perfect place for them to call their own while they read , eat snacks , watch tv , or nap . this marshmallow furniture children 's 2-in-1 flip open foam futon-style sofa is made of lightweight foam so kiddos can move it around from room to room themselves , flipping it open into a bed or folding it back into a sofa . this kid 's sofa makes a great gift , and it will fit right into playrooms , bedrooms , living rooms , daycare , sleepovers , vacations , or nap time . this particular marshmallow furniture kids sofa comes with a fun disney pixar cars 3 print , and parents will love the machine-washable zippered polyester fabric slipcover .",
#   'score': 26.853947281837463},
#  {'id': 824,
#   'title': 'double chaise lounge floor couch',
#   'description': "the multi-functional lazy sofa is becoming a popular trend for people to enjoy themselves after their tiring work every day . it is great for almost every place , such as living room , bedroom , home office , dorm room , balcony , and outdoor space , and suitable for watching tv , play games , working on a laptop , or take a nap in it . you wo n't be disappointed with this purchase . lean back and get comfortable after a long day with the leisure sofa bed with a built-in 5 gear back adjuster system and take floor comfort to the next level . the built-in back adjuster system allows the chair to easily take on 5 different angled positions from 90 degrees in an upright chair position to 180 degrees flatbed position , satisfying any and all posture requirements for a customized seating experience .",
#   'score': 25.523414611816406},
#  {'id': 10320,
#   'title': 'nava couch owl throw pillow',
#   'description': 'the manufacturer works with artists from around the world to create astounding and unique home decor products . toss this decorative pillow on any bed , sofa or chair , and add personality to your chic and stylish decor . lay your head against your new art and relax ! all orders are subject to a possible shipping credit if you order a combination of products and pieces in one order . each purchase supports the artist who created the image . made of woven polyester material that is super soft and cozy . includes a cushy supportive pillow insert , zipped inside . dye-sublimation printing adheres the ink to the material for long life and durability .',
#   'score': 25.523414611816406},
#  {'id': 10322,
#   'title': 'rundle couch bubbles throw pillow',
#   'description': 'the manufacturer works with artists from around the world to create astouding and unique home decor products . toss this decorative pillow on any bed , sofa or chair , and add personality to your chic and stylish decor . lay your head against your new art and relax ! all orders are subject to a possible shipping credit if you order a combination of products and pieces in one order . each purchase supports the artist who created the image . made of woven polyester material that is super soft and cozy . includes a cushy supportive pillow insert , zipped inside . dye sublimation printing adheres the ink to the material for long life and durability .',
#   'score': 25.523414611816406},
#  {'id': 23758,
#   'title': 'double chaise lounge sofa floor couch',
#   'description': 'the multifunctional lazy sofa has become a popular trend for people to enjoy life after hard work every day . it can be placed almost everywhere , such as living room , bedroom , home office , dormitory , balcony , and outdoor space . it is very suitable for you to watch tv , play games , play on your laptop , or have a nap . therefore , this purchase will definitely not disappoint you . this built-in leisure sofa features a 5-gear back adjustment system that allows you to enjoy comfort after a busy day . this sofa , from 90 degrees in an upright chair position to a 180 degrees flatbed position , can satisfy any posture requirements of you to achieve a customized seating experience and provide you with a new solution to increase floor comfort .',
#   'score': 23.870174407958984},
#  {'id': 33593,
#   'title': 'sectional couch with reversible chaise modern l-shape sofa 3-seat couch modular sectional sofa',
#   'description': 'this reversible l-shaped sofa can be a free combination . the ottoman moves left or right or middle according to your needs . even the middle seat can be move as a single seat . then 3-person seats become 2-person ‘ s . let you feel different space . the friendly design is very suitable for your home .',
#   'score': 23.251253128051758},
#  {'id': 543,
#   'title': 'waytrim indoor chaise lounge sofa , folding lazy sofa floor chair 6-position folding padded , lounger bed with armrests and a pillow chaise couch - gray',
#   'description': 'waytrim indoor chaise lounge sofa , folding lazy sofa floor chair 6-position folding padded , lounger bed with armrests and a pillow chaise couch - gray .',
#   'score': 23.161453247070312},
#  {'id': 31141,
#   'title': 'convertible sectional sofa couch , l-shaped couch with modern linen fabric for small space dark grey',
#   'description': 'small sofa and space-saving : modern and stylish design indoor sofa set fit perfectly with any indoor decor . this sofa sets clean lines , solid construction , and a comfortable finish that the whole family will love , perfect for an apartment , a studio , a condo , or a small space . this small space reversible sectional sofa that works well in any corner or living room . chaise lounge base can go on the left or right freely as you like . sports velcros on the bottom of the cushions can avoid slipping when seating .',
#   'score': 22.540176391601562},
#  {'id': 33595,
#   'title': 'convertible modular sectional sofa u shaped couch with reversible chaise modular couch sectional sofa with ottomans',
#   'description': 'filled with a high-quality sponge , making this sectional sofa is beautiful and comfortable . it can be perfectly matched with your living room or conference . for convenience and need you also can move and assemble any module , this is the charm of the modular sectional sofa !',
#   'score': 22.540176391601562}]

# %% [markdown]
# ### Structured response
#
# Here we have a simple pydantic response for the search request

# %%
from pydantic import BaseModel, Field
from typing import Optional, Literal


Categories = Literal['Furniture',
                     'Home Improvement',
                     'Décor & Pillows',
                     'Outdoor',
                     'Storage & Organization',
                     'Lighting',
                     'Rugs',
                     'Bed & Bath',
                     'Kitchen & Tabletop',
                     'Baby & Kids',
                     'School Furniture and Supplies',
                     'Appliances',
                     'Holiday Décor',
                     'Commercial Business Furniture',
                     'Pet',
                     'Contractor',
                     'Sale',
                     'Foodservice ',
                     'Reception Area',
                     'Clips']


class SearchRequest(BaseModel):
    """A simple keyword search to the furniture search index."""
    search_query: str = Field(..., description="The search query")

    category: list[Categories] = Field([], description="Filter by category, empty for no filters")


SearchRequest.model_json_schema()
# Out:
# {'description': 'A simple keyword search to the furniture search index.',
#  'properties': {'search_query': {'description': 'The search query',
#    'title': 'Search Query',
#    'type': 'string'},
#   'category': {'default': [],
#    'description': 'Filter by category, empty for no filters',
#    'items': {'enum': ['Furniture',
#      'Home Improvement',
#      'Décor & Pillows',
#      'Outdoor',
#      'Storage & Organization',
#      'Lighting',
#      'Rugs',
#      'Bed & Bath',
#      'Kitchen & Tabletop',
#      'Baby & Kids',
#      'School Furniture and Supplies',
#      'Appliances',
#      'Holiday Décor',
#      'Commercial Business Furniture',
#      'Pet',
#      'Contractor',
#      'Sale',
#      'Foodservice ',
#      'Reception Area',
#      'Clips'],
#     'type': 'string'},
#    'title': 'Category',
#    'type': 'array'}},
#  'required': ['search_query'],
#  'title': 'SearchRequest',
#  'type': 'object'}

# %% [markdown]
# ## Gather initial prompts
#
# * System prompt - the general task, to lookup furniture in our catalog to recommend
# * User prompt - what the user has given as a task (here listing the movies they like)

# %%
system_prompt = """
Users are coming to explore a catalog of furniture.

Generate a search query
"""

inputs = []
inputs.append({"role": "system", "content": system_prompt})

prompt = """
Help me find a modern couch with geometric style
"""

inputs.append({"role": "user", "content": prompt})


resp = openai.responses.parse(
    model="gpt-5",
    input=inputs,
    text_format=SearchRequest
)
resp.output_parsed
# Out:
# SearchRequest(search_query='modern geometric couch sofa contemporary angular clean lines boxy minimalist', category=['Furniture'])

# %%
furniture = search_furniture(resp.output_parsed.search_query)
furniture
# Out:
# search modern geometric couch sofa contemporary angular clean lines boxy minimalist
# [{'id': 31141,
#   'title': 'convertible sectional sofa couch , l-shaped couch with modern linen fabric for small space dark grey',
#   'description': 'small sofa and space-saving : modern and stylish design indoor sofa set fit perfectly with any indoor decor . this sofa sets clean lines , solid construction , and a comfortable finish that the whole family will love , perfect for an apartment , a studio , a condo , or a small space . this small space reversible sectional sofa that works well in any corner or living room . chaise lounge base can go on the left or right freely as you like . sports velcros on the bottom of the cushions can avoid slipping when seating .',
#   'score': 58.74964261054993},
#  {'id': 6012,
#   'title': 'francis contemporary patio sofa with cushions',
#   'description': "soak up some sun in style with this sleek patio sofa . it 's made with a clean-lined aluminum frame , so it 's not only delivering an updated take on outdoor furniture , but it also resists water and uv light . and as for that updated look , it has a streamlined design with clean , wide square arms and an open , blocky design for a modern look . this couch comes with included seat and back cushions that are made with foam filling and polyester covers , so you can kick back with a little extra padding .",
#   'score': 55.04438877105713},
#  {'id': 24984,
#   'title': 'hanoi modern & contemporary full length mirror',
#   'description': 'display classic craftsmanship with this wood-grain mirror . the clean lines of this frame have the beautiful look of black walnut . this mirror would be the perfect addition to any décor , from minimalist to rustic .',
#   'score': 53.14597702026367},
#  {'id': 24985,
#   'title': 'goliath modern & contemporary full length mirror',
#   'description': 'display classic craftsmanship with this wood-grain mirror . the clean lines of this frame have the beautiful look of black walnut . this mirror would be the perfect addition to any décor , from minimalist to rustic .',
#   'score': 53.14597702026367},
#  {'id': 33593,
#   'title': 'sectional couch with reversible chaise modern l-shape sofa 3-seat couch modular sectional sofa',
#   'description': 'this reversible l-shaped sofa can be a free combination . the ottoman moves left or right or middle according to your needs . even the middle seat can be move as a single seat . then 3-person seats become 2-person ‘ s . let you feel different space . the friendly design is very suitable for your home .',
#   'score': 51.09275960922241},
#  {'id': 654,
#   'title': 'modern l-shaped reversible sectional sofa couch with solid wood legs',
#   'description': 'this sectional sofa is the perfect way to add a sense of fashion and comfort to your home . armrests and cushions make this living room sofa more advantageous than other sofas . this high-end microfiber medieval sofa is ideal for movie nights and game nights .',
#   'score': 49.036460876464844},
#  {'id': 25692,
#   'title': 'contemporary metal braid wall décor',
#   'description': 'when it comes to building a look you love , lines should never be overlooked ! curved lines break the austerity of straight lines , creating a soft , graceful feel with the illusion of movement , while geometric patterns balance the monotony of modern spaces . styled in spirals , this wall decor does a little of both ; it brings soft , dynamic lines home as it balances out the boxy silhouettes of headboards , end tables , and similarly shaped accents . it ’ s crafted from metal and finished in silver and gold .',
#   'score': 48.32395076751709},
#  {'id': 13915,
#   'title': 'futon sofa bed modern linen upholstered couch , convertible folding recliner lounge futon couch , convertible sofa sleeper , beige pu',
#   'description': 'futon sofa can be converted to the sleeper in few seconds . the click-clack mechanism to ensure conversion between seating/lounging/ sleeping positions . 2 angles for adjusting . high-quality pu , metal legs .',
#   'score': 48.083425998687744},
#  {'id': 38685,
#   'title': 'chafin contemporary leather sofa',
#   'description': 'your office reception space speaks to who your are as a company and this black leathersoft upholstered sofa with encasing frame makes quite a statement . this trendsetting piece features a straight arm design , and foam filled , tufted , fixed back and seat cushions for exceptional comfort . leathersoft is leather and polyurethane for added softness and durability . the integrated stainless steel frame and exposed accent bar not only add style , they are rust resistant and will keep up with the rigors of commercial use . make a great impression on your clients , customers , and guests with this innovative contemporary sofa . this progressive style seating brings comfort and trend-setting style to your waiting room , reception area or home .',
#   'score': 45.32071352005005},
#  {'id': 11865,
#   'title': 'indigo stripe like horizontal lines modern minimalist 70s 80s inspired duvet cover set',
#   'description': "east urban home duvet cover sets will provide a fresh feeling throughout the night giving you a good night 's sleep . only eco-friendly inks used , no chemicals used , no dye substance harming the health of you or your pet . colors wo n't fade thanks to new digital printing methods . adds real value and depth to your bedroom decor . perfect gift idea for your mom , dad , sister , brother , grandma , grandpa , wife , husband , son , daughter , and all other beloved ones with 10 's thousands of surprising designs . a bedroom is where you spend a considerable part of your day , it 's a place to relax so enter a new world by having our bedding sets . can be at the seashore , can feel ocean waves , or meditate while staring at mountain landscapes . the digital images we display have the most accurate color possible , however , due to differences in computer monitors , we can not be responsible for variations in color between the actual product and your screen .",
#   'score': 45.119099617004395}]

# %% [markdown]
# ## Give results back to the LLM
#
# In classic RAG, we give search results back to the LLM and then ask a summary

# %%
system_prompt = """
Answer the users request. Note results have been appended to help you answer.
"""

inputs = []
inputs.append({"role": "system", "content": system_prompt})

prompt = """
Help me find a modern couch with geometric style
"""

inputs.append({"role": "user", "content": prompt})
inputs.append({"role": "user", "content": str(furniture)})

resp = openai.responses.create(
    model="gpt-5",
    input=inputs,
)
inputs += resp.output
print(resp.output)
#
# Out:
# [ResponseReasoningItem(id='rs_084f880c0f4e7ba40069820c3c1ea4819584d6c299d360c647', summary=[], type='reasoning', content=None, encrypted_content=None, status=None), ResponseOutputMessage(id='msg_084f880c0f4e7ba40069820c4dfec08195bc7d12068b84db61', content=[ResponseOutputText(annotations=[], text='Here are strong, modern options with clean, geometric lines from the results you shared:\n\n- Chafin Contemporary Leather Sofa (ID 38685)\n  - Bold geometric look: straight arms, tufted box cushions, integrated stainless steel frame. Great for a sleek, modern living room or office.\n\n- Francis Contemporary Patio Sofa with Cushions (ID 6012)\n  - Outdoor-friendly with a clean-lined aluminum frame, wide square arms, and an open, blocky silhouette. Modern and minimal.\n\n- Modern L-Shaped Reversible Sectional Sofa Couch with Solid Wood Legs (ID 654)\n  - Rectilinear profile and crisp cushions; an L-shaped form that reads very geometric while staying cozy for living rooms.\n\n- Convertible Sectional Sofa Couch, L-Shaped, Modern Linen, Dark Grey (ID 31141)\n  - Compact, clean lines, reversible chaise, and squared cushions. Good geometric look for small spaces.\n\n- Sectional Couch with Reversible Chaise, Modular L-Shape (ID 33593)\n  - Modular “block” components for a very geometric, customizable layout.\n\nIf you tell me:\n- Indoor or outdoor?\n- Size constraints (room width and preferred sofa length)?\n- Material and color (leather vs fabric, light vs dark)?\n- Budget range?\n- Need a sleeper or sectional?\n\nI’ll narrow this to the best 1–2 picks and flag any options that fit your exact dimensions.', type='output_text', logprobs=[])], role='assistant', status='completed', type='message')]

# %%
print(resp.output[-1].content[-1].text)
# Out:
# Here are strong, modern options with clean, geometric lines from the results you shared:
#
# - Chafin Contemporary Leather Sofa (ID 38685)
#   - Bold geometric look: straight arms, tufted box cushions, integrated stainless steel frame. Great for a sleek, modern living room or office.
#
# - Francis Contemporary Patio Sofa with Cushions (ID 6012)
#   - Outdoor-friendly with a clean-lined aluminum frame, wide square arms, and an open, blocky silhouette. Modern and minimal.
#
# - Modern L-Shaped Reversible Sectional Sofa Couch with Solid Wood Legs (ID 654)
#   - Rectilinear profile and crisp cushions; an L-shaped form that reads very geometric while staying cozy for living rooms.
#
# - Convertible Sectional Sofa Couch, L-Shaped, Modern Linen, Dark Grey (ID 31141)
#   - Compact, clean lines, reversible chaise, and squared cushions. Good geometric look for small spaces.
#
# - Sectional Couch with Reversible Chaise, Modular L-Shape (ID 33593)
#   - Modular “block” components for a very geometric, customizable layout.
#
# If you tell me:
# - Indoor or outdoor?
# - Size constraints (room width and preferred sofa length)?
# - Material and color (leather vs fabric, light vs dark)?
# - Budget range?
# - Need a sleeper or sectional?
#
# I’ll narrow this to the best 1–2 picks and flag any options that fit your exact dimensions.

# %% [markdown]
# ## Put all this in a chat loop
#
# This is the classic RAG loop

# %%
search_system_prompt = """
Users are coming to explore a catalog of furniture.

Generate a search query
"""

chat_system_prompt = """
Answer the users request. Note results have been appended to help you answer.
"""

search_query_inputs = []
search_query_inputs.append({"role": "system", "content": search_system_prompt})

prompt = """
Help me find a modern couch with geometric style
"""

search_query_inputs.append({"role": "user", "content": prompt})

chat_inputs = []
chat_inputs.append({"role": "system", "content": chat_system_prompt})
chat_inputs.append({"role": "user", "content": prompt})


for _ in range(5):
    resp = openai.responses.parse(
        model="gpt-5",
        input=search_query_inputs,
        text_format=SearchRequest
    )
    search_query_inputs += resp.output
    search_settings = resp.output_parsed

    furniture = search_furniture(search_settings.search_query)

    # Now take that and continue the chat
    chat_inputs.append({"role": "user", "content": str(furniture)})
    resp = openai.responses.create(
        model="gpt-5",
        input=chat_inputs,
    )
    chat_inputs += resp.output
    print(resp.output[-1].content[-1].text)
    user_response = input("User: ")
    chat_inputs.append({"role": "user", "content": user_response})
    search_query_inputs.append({"role": "user", "content": user_response})
# Out:
# search modern geometric couch sofa contemporary angular clean lines
# Great brief. From the results you shared, here are the best fits for a modern, geometric look, ranked with quick notes:
#
# Top picks
# - Chafin Contemporary Leather Sofa (id: 38685)
#   - Why it fits: Straight track arms, boxy silhouette, exposed stainless-steel frame/bar = strong geometric lines.
#   - Vibe: Sleek, architectural, contemporary/office-chic.
#   - Consider: Likely a firmer sit; black LeatherSoft (easy care, modern, slightly formal).
#
# - Francis Contemporary Patio Sofa (id: 6012)
#   - Why it fits: Clean-lined aluminum frame, wide square arms, open blocky base.
#   - Vibe: Minimal, modern outdoor piece that can read very geometric.
#   - Consider: Designed for outdoors (UV/water resistant). Works on covered patios or modern terraces.
#
# Great if you want an L-shape/small-space solution
# - Convertible Sectional Sofa, L-Shaped, Modern Linen (id: 31141)
#   - Why it fits: Clean lines and a simple, rectilinear profile; reversible chaise for layout flexibility.
#   - Vibe: Modern and compact; good for apartments.
#   - Consider: More casual/soft than the metal-framed options.
#
# - Modular Reversible L-Shape Sectional (id: 33593)
#   - Why it fits: Modular block components create a crisp geometric arrangement.
#   - Vibe: Flexible modern; can reconfigure the ottoman/center seat.
#   - Consider: Sections may shift unless connected.
#
# Also viable
# - Modern L-Shaped Reversible Sectional with Solid Wood Legs (id: 654)
#   - Why it fits: Simple modern lines; L-shape reads geometric.
#   - Consider: Details are limited; likely softer, family-friendly modern.
#
# Quick guide
# - Most striking geometric statement: Chafin (38685)
# - Outdoor geometric: Francis (6012)
# - Small space, reversible chaise: Convertible L-shape (31141)
# - Modular flexibility: Modular L-shape (33593)
#
# A few questions to zero in
# - Indoor or outdoor?
# - Sofa or sectional?
# - Upholstery preference: leather/LeatherSoft vs fabric?
# - Color palette?
# - Size constraints (max width/length) and budget range?
#
# If you share those, I’ll refine to the best match and suggest a couple of similar alternatives from other retailers if helpful.
# User: Can you find more of the L-shape ones?
# search modern geometric L-shaped sectional couch sofa corner sectional angular clean lines
# Here are more L-shaped options with a modern, geometric vibe from your results:
#
# - Moore 120.5" Wide Reversible Modular Sectional (id: 38948)
#   - Clean L silhouette, wedge back, sleek steel base = strong geometric lines. Reversible setup.
#
# - Sulligent Right-Facing Modular Corner Sectional (id: 5429)
#   - L-shape (left loveseat + right chaise). Angled chrome metal legs and straight lines for a crisp, contemporary look. Seats up to five.
#
# - Convertible L-Shaped Sectional, Modern Linen, Small Space (id: 31141)
#   - Simple rectilinear profile, reversible chaise, dark grey. Compact and apartment-friendly.
#
# - Modern L-Shaped Reversible Sectional with Solid Wood Legs (id: 654)
#   - Minimal, straight arms/cushions for a clean look. Microfiber upholstery, family-friendly.
#
# - L-Shape 3-Seat Modular with Reversible Chaise (id: 33593)
#   - Blocky modular pieces you can reconfigure; ottoman/middle seat move for layout flexibility.
#
# - Monarrez 150" Wide Corner Sectional with Double Chaise (id: 36811)
#   - Large-scale L with a double chaise on one side—big geometric presence if you have the space.
#
# Quick picks by need
# - Tightest, small-space: 31141
# - Most geometric/metal base: 38948 or 5429
# - Most modular/flexible: 33593
# - Largest statement piece: 36811
#
# Helpful to finalize:
# - Max width/depth you can fit?
# - Chaise side you want (left or right when facing the sofa)?
# - Upholstery preference (fabric vs leather) and color?
# - Budget range?
#
# Share those and I’ll narrow to the best two and flag any potential fit issues.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-657067754.py in <cell line: 0>()
#      42     chat_inputs += resp.output
#      43     print(resp.output[-1].content[-1].text)
# ---> 44     user_response = input("User: ")
#      45     chat_inputs.append({"role": "user", "content": user_response})
#      46     search_query_inputs.append({"role": "user", "content": user_response})
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
