# %% [markdown]
# ## Lesson 1 - Can we just generate blind synonyms?
#
# In this lesson we work on generating blind synonyms using LLMs. This is often the first stop for search teams.
#
# To run:
# * Either make sure Ollama is running or you have an `OPENAI_API_KEY` installed

# %%
from cheat_at_search.wands_data import products, queries
from cheat_at_search.strategy import (
    BM25Search,
    MiniLMSearch,
    EnrichedBM25Search,
    EnrichedJustRoomBM25Search,
    SynonymSearch,
)

bm25 = BM25Search(products)
# Out:
# 2025-05-28 10:06:46,920 - cheat_at_search.wands_data - INFO - Directory /Users/doug/ws/cheat-with-llms/notebooks/data/wands already exists. Skipping clone.
# 2025-05-28 10:06:46,920 - cheat_at_search.wands_data - INFO - Loading relevance labels from /Users/doug/ws/cheat-with-llms/notebooks/data/wands/dataset/label.csv
# 2025-05-28 10:06:46,984 - cheat_at_search.wands_data - INFO - Loaded 231873 relevance labels
# 2025-05-28 10:06:46,984 - cheat_at_search.wands_data - INFO - Directory /Users/doug/ws/cheat-with-llms/notebooks/data/wands already exists. Skipping clone.
# 2025-05-28 10:06:46,984 - cheat_at_search.wands_data - INFO - Loading queries from /Users/doug/ws/cheat-with-llms/notebooks/data/wands/dataset/query.csv
# 2025-05-28 10:06:46,986 - cheat_at_search.wands_data - INFO - Loaded 480 queries
# 2025-05-28 10:06:46,986 - cheat_at_search.wands_data - INFO - Directory /Users/doug/ws/cheat-with-llms/notebooks/data/wands already exists. Skipping clone.
# 2025-05-28 10:06:46,986 - cheat_at_search.wands_data - INFO - Loading products from /Users/doug/ws/cheat-with-llms/notebooks/data/wands/dataset/product.csv
# 2025-05-28 10:06:47,364 - cheat_at_search.wands_data - INFO - Loaded 42994 products
# /Users/doug/ws/cheat-with-llms/cheat_at_search/wands_data.py:83: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['product_description'].fillna('', inplace=True)
# /Users/doug/ws/cheat-with-llms/cheat_at_search/wands_data.py:84: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['product_name'].fillna('', inplace=True)
# 2025-05-28 10:06:50,313 - searcharray.indexing - INFO - Indexing begins w/ 4 workers
# 2025-05-28 10:06:50,314 - searcharray.indexing - INFO - 0 Batch Start tokenization
# 2025-05-28 10:06:50,315 - searcharray.indexing - INFO - Tokenizing 42994 documents
# 2025-05-28 10:06:50,413 - searcharray.indexing - INFO - Tokenized 10000 (23.259059403637718%)
# 2025-05-28 10:06:50,507 - searcharray.indexing - INFO - Tokenized 20000 (46.518118807275435%)
# 2025-05-28 10:06:50,602 - searcharray.indexing - INFO - Tokenized 30000 (69.77717821091315%)
# 2025-05-28 10:06:50,695 - searcharray.indexing - INFO - Tokenized 40000 (93.03623761455087%)
# 2025-05-28 10:06:50,740 - searcharray.indexing - INFO - Tokenization -- vstacking
# 2025-05-28 10:06:50,741 - searcharray.indexing - INFO - Tokenization -- DONE
# 2025-05-28 10:06:50,742 - searcharray.indexing - INFO - Inverting docs->terms
# 2025-05-28 10:06:50,760 - searcharray.indexing - INFO - Encoding positions to bit array
# 2025-05-28 10:06:50,773 - searcharray.indexing - INFO - Batch tokenization complete
# 2025-05-28 10:06:50,774 - searcharray.indexing - INFO - (main thread) Processing 1 batch results
# 2025-05-28 10:06:50,783 - searcharray.indexing - INFO - Indexing from tokenization complete
# 2025-05-28 10:06:50,791 - searcharray.indexing - INFO - Indexing begins w/ 4 workers
# 2025-05-28 10:06:50,793 - searcharray.indexing - INFO - 0 Batch Start tokenization
# 2025-05-28 10:06:50,793 - searcharray.indexing - INFO - Tokenizing 42994 documents
# 2025-05-28 10:06:51,140 - searcharray.indexing - INFO - Tokenized 10000 (23.259059403637718%)
# 2025-05-28 10:06:51,490 - searcharray.indexing - INFO - Tokenized 20000 (46.518118807275435%)
# 2025-05-28 10:06:51,859 - searcharray.indexing - INFO - Tokenized 30000 (69.77717821091315%)
# 2025-05-28 10:06:52,221 - searcharray.indexing - INFO - Tokenized 40000 (93.03623761455087%)
# 2025-05-28 10:06:52,367 - searcharray.indexing - INFO - Tokenization -- vstacking
# 2025-05-28 10:06:52,371 - searcharray.indexing - INFO - Tokenization -- DONE
# 2025-05-28 10:06:52,377 - searcharray.indexing - INFO - Inverting docs->terms
# 2025-05-28 10:06:52,651 - searcharray.indexing - INFO - Encoding positions to bit array
# 2025-05-28 10:06:52,697 - searcharray.indexing - INFO - Batch tokenization complete
# 2025-05-28 10:06:52,698 - searcharray.indexing - INFO - (main thread) Processing 1 batch results
# 2025-05-28 10:06:52,752 - searcharray.indexing - INFO - Indexing from tokenization complete

# %%
from cheat_at_search.eval import grade_results

results = bm25.search_all(queries)
graded = grade_results(
    results,
    max_grade=2,
    k=10,
)

idcg = graded['idcg'].iloc[0]
dcgs = graded.groupby(["query", 'query_id'])["discounted_gain"].sum().sort_values(ascending=False).rename('dcg')
ndcgs = dcgs / idcg
ndcgs = ndcgs.rename('ndcg')

graded = graded.merge(dcgs, on=['query', 'query_id'])
graded = graded.merge(ndcgs, on=['query', 'query_id'])

graded
# Out:
# /Users/doug/ws/cheat-with-llms/cheat_at_search/eval.py:18: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   graded_results['grade'].fillna(0, inplace=True)
#       product_id                                       product_name  \
# 0           7465                                   hair salon chair
# 1           7468  mercer41 hair salon chair hydraulic styling ch...
# 2          25431                      barberpub salon massage chair
# 3          25432  barberpub hydraulic salon spa reclining massag...
# 4          15612                                      massage chair
# ...          ...                                                ...
# 4795       40243                    madisen hanging wine glass rack
# 4796       40244                       kena hanging wine glass rack
# 4797       39976                       wall mounted wine glass rack
# 4798       40247                       winn hanging wine glass rack
# 4799       40245                   podgorni hanging wine glass rack
#
#                  product_class  \
# 0     Massage Chairs|Recliners
# 1               Massage Chairs
# 2               Massage Chairs
# 3     Massage Chairs|Recliners
# 4               Massage Chairs
# ...                        ...
# 4795                Wine Racks
# 4796                Wine Racks
# 4797                Wine Racks
# 4798                Wine Racks
# 4799                Wine Racks
#
#                                      category hierarchy  \
# 0     Furniture / Living Room Furniture / Chairs & S...
# 1     Furniture / Living Room Furniture / Chairs & S...
# 2     Furniture / Living Room Furniture / Chairs & S...
# 3     Furniture / Living Room Furniture / Chairs & S...
# 4     Furniture / Living Room Furniture / Chairs & S...
# ...                                                 ...
# 4795  Kitchen & Tabletop / Tableware & Drinkware / B...
# 4796  Kitchen & Tabletop / Tableware & Drinkware / B...
# 4797  Kitchen & Tabletop / Tableware & Drinkware / B...
# 4798  Kitchen & Tabletop / Tableware & Drinkware / B...
# 4799  Kitchen & Tabletop / Tableware & Drinkware / B...
#
#                                     product_description  \
# 0     offers a wide selection of professional salon ...
# 1     mercer41 beauty offers a wide selection profes...
# 2     salon chairs are a wonderful avenue for hairst...
# 3     salon chairs are a wonderful avenue for hairst...
# 4     features heavy duty steel frame . premium chro...
# ...                                                 ...
# 4795  complement your farmhouse kitchen decor with t...
# 4796  spruce up your farmhouse kitchen decor with th...
# 4797  the latest addition to this collection , this ...
# 4798  are you looking for a safe and decorative solu...
# 4799  display and protect your delicate wine or marg...
#
#                                        product_features  rating_count  \
# 0     fauxleathertype : pu|legheight-toptobottom:18|...          69.0
# 1     seatfillmaterial : foam|waterrepellant : no re...           1.0
# 2     supplierintendedandapproveduse : non residenti...           4.0
# 3     backheight-seattotopofback:15.7|recliningtyped...           5.0
# 4     overallheight-toptobottom:35.5|productcare : d...          59.0
# ...                                                 ...           ...
# 4795  producttype : wine glass rack|overallwidth-sid...          29.0
# 4796  warrantylength:1 year|producttype : wine glass...          23.0
# 4797  overallheight-toptobottom:4|design : wall moun...          34.0
# 4798  overallheight-toptobottom:1.5|overallwidth-sid...         305.0
# 4799  overallheight-toptobottom:1.5|stemwarecapacity...           6.0
#
#       average_rating  review_count  \
# 0                4.5          53.0
# 1                5.0           1.0
# 2                5.0           4.0
# 3                4.0           5.0
# 4                4.5          50.0
# ...              ...           ...
# 4795             5.0          20.0
# 4796             5.0          18.0
# 4797             4.5          18.0
# 4798             5.0         187.0
# 4799             4.0           6.0
#
#                                                features  ... query_id rank  \
# 0     [fauxleathertype : pu, legheight-toptobottom:1...  ...        0    1
# 1     [seatfillmaterial : foam, waterrepellant : no ...  ...        0    2
# 2     [supplierintendedandapproveduse : non resident...  ...        0    3
# 3     [backheight-seattotopofback:15.7, recliningtyp...  ...        0    4
# 4     [overallheight-toptobottom:35.5, productcare :...  ...        0    5
# ...                                                 ...  ...      ...  ...
# 4795  [producttype : wine glass rack, overallwidth-s...  ...      487    6
# 4796  [warrantylength:1 year, producttype : wine gla...  ...      487    7
# 4797  [overallheight-toptobottom:4, design : wall mo...  ...      487    8
# 4798  [overallheight-toptobottom:1.5, overallwidth-s...  ...      487    9
# 4799  [overallheight-toptobottom:1.5, stemwarecapaci...  ...      487   10
#
#          query_class     id  label  grade discounted_gain      idcg       dcg  \
# 0     Massage Chairs   80.0  Exact    2.0            3.00  8.786905  8.536905
# 1     Massage Chairs  104.0  Exact    2.0            1.50  8.786905  8.536905
# 2     Massage Chairs   29.0  Exact    2.0            1.00  8.786905  8.536905
# 3     Massage Chairs   28.0  Exact    2.0            0.75  8.786905  8.536905
# 4     Massage Chairs  101.0  Exact    2.0            0.60  8.786905  8.536905
# ...              ...    ...    ...    ...             ...       ...       ...
# 4795             NaN    NaN    NaN    0.0            0.00  8.786905  0.000000
# 4796             NaN    NaN    NaN    0.0            0.00  8.786905  0.000000
# 4797             NaN    NaN    NaN    0.0            0.00  8.786905  0.000000
# 4798             NaN    NaN    NaN    0.0            0.00  8.786905  0.000000
# 4799             NaN    NaN    NaN    0.0            0.00  8.786905  0.000000
#
#           ndcg
# 0     0.971549
# 1     0.971549
# 2     0.971549
# 3     0.971549
# 4     0.971549
# ...        ...
# 4795  0.000000
# 4796  0.000000
# 4797  0.000000
# 4798  0.000000
# 4799  0.000000
#
# [4800 rows x 24 columns]

# %%
from cheat_at_search.wands_data import labeled_queries

ideal_results = labeled_queries.sort_values(['query_id', 'grade'], ascending=(True, False))
ideal_results['rank'] = ideal_results.groupby('query_id').cumcount() + 1
ideal_top_10 = ideal_results[ideal_results['rank'] <= 10] \
    .add_prefix('ideal_') \
    .rename(columns={'ideal_query_id': 'query_id', 'ideal_query': 'query'})

ideal_top_10 = ideal_top_10.merge(
    products[['product_id', 'product_name']], how='left', left_on='ideal_product_id', right_on='product_id'
).rename(columns={'product_name': 'ideal_product_name'}).drop(columns='ideal_query_class')

ideal_top_10
# Out:
#       query_id        query  ideal_product_id  ideal_id ideal_label  \
# 0            0  salon chair              1197        99       Exact
# 1            0  salon chair              1198       116       Exact
# 2            0  salon chair              2636         3       Exact
# 3            0  salon chair              2638        66       Exact
# 4            0  salon chair              5936        10       Exact
# ...        ...          ...               ...       ...         ...
# 4732       487   rack glass               110    202050     Partial
# 4733       487   rack glass               285    202336     Partial
# 4734       487   rack glass               573    202462     Partial
# 4735       487   rack glass               635    202178     Partial
# 4736       487   rack glass               660    202351     Partial
#
#       ideal_grade  ideal_rank  product_id  \
# 0             2.0           1        1197
# 1             2.0           2        1198
# 2             2.0           3        2636
# 3             2.0           4        2638
# 4             2.0           5        5936
# ...           ...         ...         ...
# 4732          1.0           6         110
# 4733          1.0           7         285
# 4734          1.0           8         573
# 4735          1.0           9         635
# 4736          1.0          10         660
#
#                                      ideal_product_name
# 0     lizzy 25.6 '' w bariatric antimicrobial waitin...
# 1     rackham 26.8 '' w bariatric antimicrobial pvc ...
# 2     25 '' wide faux leather manual swivel standard...
# 3                            faux leather massage chair
# 4     69 '' w metal seat waiting room chair with met...
# ...                                                 ...
# 4732                 west harptree 34 '' w garment rack
# 4733                       3 shelf movable storage rack
# 4734                    5 - hook freestanding coat rack
# 4735                    4 - hook freestanding coat rack
# 4736                  strine shoe clothing storage rack
#
# [4737 rows x 9 columns]

# %%
graded_view = graded[['query_id', 'query', 'rank', 'product_id', 'product_name',  'grade', 'dcg', 'ndcg']].rename(
                      columns={'product_id': 'product_id_actual', 'product_name': 'product_name_actual'})

side_by_side = ideal_top_10.merge(graded_view, 
                                  how='left',
                                  left_on=['query_id', 'query', 'ideal_rank'],
                                  right_on=['query_id', 'query', 'rank'])
side_by_side
# Out:
#       query_id        query  ideal_product_id  ideal_id ideal_label  \
# 0            0  salon chair              1197        99       Exact
# 1            0  salon chair              1198       116       Exact
# 2            0  salon chair              2636         3       Exact
# 3            0  salon chair              2638        66       Exact
# 4            0  salon chair              5936        10       Exact
# ...        ...          ...               ...       ...         ...
# 4732       487   rack glass               110    202050     Partial
# 4733       487   rack glass               285    202336     Partial
# 4734       487   rack glass               573    202462     Partial
# 4735       487   rack glass               635    202178     Partial
# 4736       487   rack glass               660    202351     Partial
#
#       ideal_grade  ideal_rank  product_id  \
# 0             2.0           1        1197
# 1             2.0           2        1198
# 2             2.0           3        2636
# 3             2.0           4        2638
# 4             2.0           5        5936
# ...           ...         ...         ...
# 4732          1.0           6         110
# 4733          1.0           7         285
# 4734          1.0           8         573
# 4735          1.0           9         635
# 4736          1.0          10         660
#
#                                      ideal_product_name  rank  \
# 0     lizzy 25.6 '' w bariatric antimicrobial waitin...     1
# 1     rackham 26.8 '' w bariatric antimicrobial pvc ...     2
# 2     25 '' wide faux leather manual swivel standard...     3
# 3                            faux leather massage chair     4
# 4     69 '' w metal seat waiting room chair with met...     5
# ...                                                 ...   ...
# 4732                 west harptree 34 '' w garment rack     6
# 4733                       3 shelf movable storage rack     7
# 4734                    5 - hook freestanding coat rack     8
# 4735                    4 - hook freestanding coat rack     9
# 4736                  strine shoe clothing storage rack    10
#
#       product_id_actual                                product_name_actual  \
# 0                  7465                                   hair salon chair
# 1                  7468  mercer41 hair salon chair hydraulic styling ch...
# 2                 25431                      barberpub salon massage chair
# 3                 25432  barberpub hydraulic salon spa reclining massag...
# 4                 15612                                      massage chair
# ...                 ...                                                ...
# 4732              40243                    madisen hanging wine glass rack
# 4733              40244                       kena hanging wine glass rack
# 4734              39976                       wall mounted wine glass rack
# 4735              40247                       winn hanging wine glass rack
# 4736              40245                   podgorni hanging wine glass rack
#
#       grade       dcg      ndcg
# 0       2.0  8.536905  0.971549
# 1       2.0  8.536905  0.971549
# 2       2.0  8.536905  0.971549
# 3       2.0  8.536905  0.971549
# 4       2.0  8.536905  0.971549
# ...     ...       ...       ...
# 4732    0.0  0.000000  0.000000
# 4733    0.0  0.000000  0.000000
# 4734    0.0  0.000000  0.000000
# 4735    0.0  0.000000  0.000000
# 4736    0.0  0.000000  0.000000
#
# [4737 rows x 15 columns]

# %%
side_by_side[side_by_side['query'] == 'ottoman bed queen']
# Out:
#       query_id              query  ideal_product_id  ideal_id ideal_label  \
# 3381       344  ottoman bed queen               545     37893     Partial
# 3382       344  ottoman bed queen               998     37883     Partial
# 3383       344  ottoman bed queen              1030     37836     Partial
# 3384       344  ottoman bed queen              1367     37901     Partial
# 3385       344  ottoman bed queen              1537     37873     Partial
# 3386       344  ottoman bed queen              1563     37894     Partial
# 3387       344  ottoman bed queen              1730     37910     Partial
# 3388       344  ottoman bed queen              1753     37854     Partial
# 3389       344  ottoman bed queen              1844     37889     Partial
# 3390       344  ottoman bed queen              1927     37864     Partial
#
#       ideal_grade  ideal_rank  product_id  \
# 3381          1.0           1         545
# 3382          1.0           2         998
# 3383          1.0           3        1030
# 3384          1.0           4        1367
# 3385          1.0           5        1537
# 3386          1.0           6        1563
# 3387          1.0           7        1730
# 3388          1.0           8        1753
# 3389          1.0           9        1844
# 3390          1.0          10        1927
#
#                                      ideal_product_name  rank  \
# 3381                            loggins storage ottoman     1
# 3382  karlsefni 37.5 '' wide tufted rectangle standa...     2
# 3383            48 '' tufted rectangle standard ottoman     3
# 3384        roft 50 '' tufted rectangle storage ottoman     4
# 3385       henninger 25 '' tufted round storage ottoman     5
# 3386  luper 41.75 '' wide tufted rectangle storage o...     6
# 3387                             tufted storage ottoman     7
# 3388  camden 28.5 '' wide square folding bed cocktai...     8
# 3389          lampkins 24 '' rectangle standard ottoman     9
# 3390  denali 51.18 '' wide faux leather rectangle st...    10
#
#       product_id_actual                           product_name_actual  grade  \
# 3381               2089                 elzadie queen four poster bed    0.0
# 3382              38301         sinead queen upholstered platform bed    0.0
# 3383              14834  abbot diamond queen upholstered standard bed    0.0
# 3384               7371     carrollton queen upholstered standard bed    0.0
# 3385              29090      lamberton queen upholstered platform bed    0.0
# 3386              17289                 masonville queen platform bed    0.0
# 3387              17219     bianaca queen low profile four poster bed    0.0
# 3388               6503       karmakar queen upholstered platform bed    0.0
# 3389              34268                   fabienne queen standard bed    0.0
# 3390              32412         louque queen upholstered platform bed    0.0
#
#       dcg  ndcg
# 3381  0.0   0.0
# 3382  0.0   0.0
# 3383  0.0   0.0
# 3384  0.0   0.0
# 3385  0.0   0.0
# 3386  0.0   0.0
# 3387  0.0   0.0
# 3388  0.0   0.0
# 3389  0.0   0.0
# 3390  0.0   0.0

# %%
side_by_side.groupby('query')['ndcg'].max().sort_values()
# Out:
# query
# one alium way              0.0
# merlyn 6                   0.0
# ottoman bed queen          0.0
# white abstract             0.0
# large bases                0.0
#                           ...
# toilet paper stand         1.0
# retractable side awning    1.0
# delta trinsic              1.0
# desk and chair set         1.0
# kids chair                 1.0
# Name: ndcg, Length: 480, dtype: float64

# %%
merlyn_6 = labeled_queries[labeled_queries['query'] == 'merlyn 6'].sort_values('grade', ascending=False)
merlyn_6[merlyn_6['product_id'] == 8531]
# Out:
#         query_id     query                query_class  product_id      id  \
# 141127       304  merlyn 6  Outdoor Conversation Sets        8531  131167
#
#           label  grade
# 141127  Partial    1.0

# %%
products[products['product_id'] == 8531]
# Out:
#       product_id                 product_name          product_class  \
# 8531        8531  open console with 6 drawers  Sofa & Console Tables
#
#                                      category hierarchy  \
# 8531  Furniture / Living Room Furniture / Console Ta...
#
#                                     product_description  \
# 8531  crafted in italy , in timeless design , this i...
#
#                                        product_features  rating_count  \
# 8531  topmaterial : solid wood|countryoforigin : ita...           NaN
#
#       average_rating  review_count  \
# 8531             NaN           NaN
#
#                                                features  \
# 8531  [topmaterial : solid wood, countryoforigin : i...
#
#                                  product_name_snowball  \
# 8531  Terms({'drawer', 'open', '6', 'consol', 'with'})
#
#                            product_description_snowball
# 8531  Terms({'design', 'itali', 'will', 'space', 'in...

# %%
import numpy as np
query_sample = side_by_side['query'].unique()
np.random.shuffle(query_sample)
query_sample = query_sample[:5]
query_sample
# Out:
# array(['parsons chairs', 'pedistole sink', 'penny round tile',
#        'benjiamino faux leather power lift chair', 'shoe closet'],
#       dtype=object)

# %%
print(side_by_side[side_by_side['query'].isin(query_sample)].to_markdown())
# Out:
# |      |   query_id | query                                    |   ideal_product_id |   ideal_id | ideal_label   |   ideal_grade |   ideal_rank |   product_id | ideal_product_name                                                                             |   rank |   product_id_actual | product_name_actual                                                                  |   grade |      dcg |      ndcg |
# |-----:|-----------:|:-----------------------------------------|-------------------:|-----------:|:--------------|--------------:|-------------:|-------------:|:-----------------------------------------------------------------------------------------------|-------:|--------------------:|:-------------------------------------------------------------------------------------|--------:|---------:|----------:|
# | 1801 |        182 | penny round tile                         |               3580 |      25875 | Exact         |             2 |            1 |         3580 | 1 '' x 1 '' marble penny round mosaic tile                                                     |      1 |               12845 | penny 0.8 '' x 0.8 '' porcelain penny round mosaic floor tile                        |       2 | 8.7869   | 1         |
# | 1802 |        182 | penny round tile                         |              10663 |      25920 | Exact         |             2 |            2 |        10663 | polka 1 '' x 1 '' penny round mosaic tile                                                      |      2 |               24216 | penny rounds 1 '' x 1 '' marble mosaic tile in white/gray                            |       2 | 8.7869   | 1         |
# | 1803 |        182 | penny round tile                         |              10664 |      25919 | Exact         |             2 |            3 |        10664 | pixie 0.75 '' x 0.75 '' glass penny round mosaic wall & floor tile                             |      3 |               29774 | vulcan ceramic penny round mosaic wall & floor tile                                  |       2 | 8.7869   | 1         |
# | 1804 |        182 | penny round tile                         |              10666 |      25894 | Exact         |             2 |            4 |        10666 | orb 0.75 '' x 0.75 '' metal penny round mosaic tile                                            |      4 |               12828 | penny 1 '' x 1 '' porcelain penny round mosaic wall & floor tile                     |       2 | 8.7869   | 1         |
# | 1805 |        182 | penny round tile                         |              11458 |      25873 | Exact         |             2 |            5 |        11458 | 0.8 '' x 0.8 '' porcelain penny round mosaic wall & floor tile                                 |      5 |               27093 | penny 12 '' x 12 '' porcelain penny round mosaic tile                                |       2 | 8.7869   | 1         |
# | 1806 |        182 | penny round tile                         |              12371 |      25899 | Exact         |             2 |            6 |        12371 | penny 0.8 '' x 0.8 '' metal mosaic tile                                                        |      6 |               36095 | penny round 0.75 '' x 0.75 '' marble mosaic tile in bianco carrara                   |       2 | 8.7869   | 1         |
# | 1807 |        182 | penny round tile                         |              12372 |      25913 | Exact         |             2 |            7 |        12372 | penny round 12 '' x 11 '' metal mosaic tile                                                    |      7 |               12823 | penny 0.8 '' x 0.8 '' porcelain mosaic tile                                          |       2 | 8.7869   | 1         |
# | 1808 |        182 | penny round tile                         |              12377 |      25874 | Exact         |             2 |            8 |        12377 | 0.9 '' x 0.9 '' metal penny round mosaic wall tile                                             |      8 |               29763 | penny 0.8 '' x 0.8 '' porcelain penny round mosaic wall and floor tile               |       2 | 8.7869   | 1         |
# | 1809 |        182 | penny round tile                         |              12779 |      25925 | Exact         |             2 |            9 |        12779 | retro 1 '' x 1 '' porcelain penny round mosaic wall & floor tile                               |      9 |               12371 | penny 0.8 '' x 0.8 '' metal mosaic tile                                              |       2 | 8.7869   | 1         |
# | 1810 |        182 | penny round tile                         |              12807 |      25923 | Exact         |             2 |           10 |        12807 | retro 0.75 '' x 0.75 '' porcelain mosaic penny round wall & floor tile                         |     10 |               12867 | penny 1 '' x 1 '' porcelain round mosaic wall & floor tile                           |       2 | 8.7869   | 1         |
# | 1871 |        190 | benjiamino faux leather power lift chair |               1144 |     104293 | Exact         |             2 |            1 |         1144 | guinee genuine leather executive chair                                                         |      1 |               36038 | rimini 35.4 '' wide faux leather power lift assist recliner                          |       1 | 2.92897  | 0.333333  |
# | 1872 |        190 | benjiamino faux leather power lift chair |               1272 |     104295 | Exact         |             2 |            2 |         1272 | demars leather task chair                                                                      |      2 |               31460 | rucinski 31.5 '' wide faux leather power lift assist recliner                        |       1 | 2.92897  | 0.333333  |
# | 1873 |        190 | benjiamino faux leather power lift chair |              29744 |     104296 | Exact         |             2 |            3 |        29744 | genuine leather reclining adjustable width massage chair                                       |      3 |                7718 | lannie 33 '' wide faux leather power lift assist standard recliner                   |       1 | 2.92897  | 0.333333  |
# | 1874 |        190 | benjiamino faux leather power lift chair |              34403 |     104294 | Exact         |             2 |            4 |        34403 | hortencia genuine leather conference chair                                                     |      4 |               26681 | beggs 35.8 '' wide faux leather power lift assist standard recliner                  |       1 | 2.92897  | 0.333333  |
# | 1875 |        190 | benjiamino faux leather power lift chair |              38674 |     104297 | Exact         |             2 |            5 |        38674 | rosina 118.125 '' wide faux leather reversible sofa & chaise                                   |      5 |                7723 | 36.25 '' wide faux leather power lift assist standard recliner                       |       1 | 2.92897  | 0.333333  |
# | 1876 |        190 | benjiamino faux leather power lift chair |                 63 |     104277 | Partial       |             1 |            6 |           63 | 33 '' wide genuine leather wingback chair                                                      |      6 |                2846 | hadsell 35.8 '' wide faux leather power lift assist standard recliner                |       1 | 2.92897  | 0.333333  |
# | 1877 |        190 | benjiamino faux leather power lift chair |                113 |     104688 | Partial       |             1 |            7 |          113 | kaden 33.1 '' wide velvet power lift assist standard recliner                                  |      7 |               15437 | pham 25.1 '' wide faux leather power lift assist standard recliner                   |       1 | 2.92897  | 0.333333  |
# | 1878 |        190 | benjiamino faux leather power lift chair |                114 |     104590 | Partial       |             1 |            8 |          114 | 31 '' wide velvet power lift assist standard recliner with massager                            |      8 |               27528 | courtois 34.6 '' wide faux leather power lift assist standard recliner with massager |       1 | 2.92897  | 0.333333  |
# | 1879 |        190 | benjiamino faux leather power lift chair |                209 |     104177 | Partial       |             1 |            9 |          209 | fashion casual lift chair office work chair beauty salon chair black                           |      9 |                5452 | gunveig 33.5 '' wide faux leather power lift assist standard recliner                |       1 | 2.92897  | 0.333333  |
# | 1880 |        190 | benjiamino faux leather power lift chair |                289 |     104093 | Partial       |             1 |           10 |          289 | 31 '' wide tufted top grain leather club chair                                                 |     10 |               18007 | borovno 41 '' wide faux leather power lift assist zero gravity recliner              |       1 | 2.92897  | 0.333333  |
# | 4250 |        435 | shoe closet                              |                660 |      46468 | Exact         |             2 |            1 |          660 | strine shoe clothing storage rack                                                              |      1 |               41969 | shoe closet storage accessory                                                        |       2 | 7.46468  | 0.849524  |
# | 4251 |        435 | shoe closet                              |                661 |      46469 | Exact         |             2 |            2 |          661 | striplin 55.11 '' w shoe clothing rack                                                         |      2 |               22445 | cube closet 12 pair shoe storage cabinet                                             |       2 | 7.46468  | 0.849524  |
# | 4252 |        435 | shoe closet                              |               2327 |      46416 | Exact         |             2 |            3 |         2327 | flip flop 7 pair hanging shoe organizer                                                        |      3 |               22446 | modular closet shoe storage cabinet                                                  |       2 | 7.46468  | 0.849524  |
# | 4253 |        435 | shoe closet                              |               3549 |      46404 | Exact         |             2 |            4 |         3549 | eindhoven 21 pair shoe storage cabinet                                                         |      4 |               39396 | closet organizer 45 pair shoe storage cabinet                                        |       1 | 7.46468  | 0.849524  |
# | 4254 |        435 | shoe closet                              |               3962 |      46437 | Exact         |             2 |            5 |         3962 | maximize 16 pair stackable shoe storage cabinet                                                |      5 |               17566 | 48 '' w closet system                                                                |       1 | 7.46468  | 0.849524  |
# | 4255 |        435 | shoe closet                              |               6331 |      46338 | Exact         |             2 |            6 |         6331 | 12 pair shoe storage cabinet                                                                   |      6 |               39393 | closet rack shelf organizer 27 pair shoe storage cabinet                             |       2 | 7.46468  | 0.849524  |
# | 4256 |        435 | shoe closet                              |               7549 |      46354 | Exact         |             2 |            7 |         7549 | 25 pair stackable shoe rack                                                                    |      7 |               39397 | portable closet cover 36 pair shoe storage cabinet                                   |       2 | 7.46468  | 0.849524  |
# | 4257 |        435 | shoe closet                              |               7555 |      46470 | Exact         |             2 |            8 |         7555 | suitesymphony 23.7 '' w shelving                                                               |      8 |               36433 | shoe storage box                                                                     |       2 | 7.46468  | 0.849524  |
# | 4258 |        435 | shoe closet                              |              10305 |      46465 | Exact         |             2 |            9 |        10305 | stackable shoe storage boxes                                                                   |      9 |               28622 | 20 pair shoe rack                                                                    |       1 | 7.46468  | 0.849524  |
# | 4259 |        435 | shoe closet                              |              11202 |      46440 | Exact         |             2 |           10 |        11202 | modular storage 21 '' w shelving                                                               |     10 |               24505 | adjustable 15 pair shoe rack                                                         |       1 | 7.46468  | 0.849524  |
# | 4290 |        439 | parsons chairs                           |                369 |     185597 | Exact         |             2 |            1 |          369 | herschel upholstered parsons chair                                                             |      1 |               26961 | lainey parsons chair                                                                 |       2 | 8.7869   | 1         |
# | 4291 |        439 | parsons chairs                           |                451 |      46982 | Exact         |             2 |            2 |          451 | olin upholstered side chair                                                                    |      2 |                1795 | tenbury upholstered parsons chair                                                    |       2 | 8.7869   | 1         |
# | 4292 |        439 | parsons chairs                           |                486 |      47010 | Exact         |             2 |            3 |          486 | vanslyke floral upholstered dining chair                                                       |      3 |               38686 | aona upholstered parsons chair                                                       |       2 | 8.7869   | 1         |
# | 4293 |        439 | parsons chairs                           |                487 |      47011 | Exact         |             2 |            4 |          487 | vassar tufted side upholstered dining chair                                                    |      4 |               24778 | wallington parsons chair                                                             |       2 | 8.7869   | 1         |
# | 4294 |        439 | parsons chairs                           |                701 |     187886 | Exact         |             2 |            5 |          701 | stingley velvet parsons chair                                                                  |      5 |               14842 | painesville upholstered parsons chair                                                |       2 | 8.7869   | 1         |
# | 4295 |        439 | parsons chairs                           |                702 |     185992 | Exact         |             2 |            6 |          702 | stidham tufted velvet parsons chair                                                            |      6 |               14845 | painesville upholstered parsons chair                                                |       2 | 8.7869   | 1         |
# | 4296 |        439 | parsons chairs                           |                703 |     187132 | Exact         |             2 |            7 |          703 | stiefel velvet parsons chair                                                                   |      7 |                4120 | hoxton upholstered parsons chair                                                     |       2 | 8.7869   | 1         |
# | 4297 |        439 | parsons chairs                           |                706 |     187135 | Exact         |             2 |            8 |          706 | nordquist folding parsons chair                                                                |      8 |                4367 | zariyah parsons trellis upholstered dining chair                                     |       2 | 8.7869   | 1         |
# | 4298 |        439 | parsons chairs                           |               1020 |      57242 | Exact         |             2 |            9 |         1020 | iolanta upholstered parsons chair in gray                                                      |      9 |               22813 | adelayne upholstered parsons chair in pink                                           |       2 | 8.7869   | 1         |
# | 4299 |        439 | parsons chairs                           |               1373 |      46911 | Exact         |             2 |           10 |         1373 | clermont upholstered dining chair                                                              |     10 |               10705 | arline parsons chair                                                                 |       2 | 8.7869   | 1         |
# | 4707 |        485 | pedistole sink                           |               1301 |     201639 | Partial       |             1 |            1 |         1301 | 33 '' l x 22 '' w farmhouse/apron kitchen sink with basket strainer and drain assembly         |      1 |               36856 | stainless steel sink frame                                                           |       0 | 0.433333 | 0.0493158 |
# | 4708 |        485 | pedistole sink                           |               1303 |     201528 | Partial       |             1 |            2 |         1303 | 33 '' l x 20 '' w double basin farmhouse/apron kitchen sink with sink grid and basket strainer |      2 |               18943 | sink leg                                                                             |       0 | 0.433333 | 0.0493158 |
# | 4709 |        485 | pedistole sink                           |               1440 |     201612 | Partial       |             1 |            3 |         1440 | roald bulanka 72 '' double sink bathroom vanity                                                |      3 |               21545 | 33 '' l x 22 '' w farmhouse kitchen sink with sink grid and strainer                 |       1 | 0.433333 | 0.0493158 |
# | 4710 |        485 | pedistole sink                           |               2271 |     201643 | Partial       |             1 |            4 |         2271 | double basin 30 '' l x 22 '' w farmhouse/apron kitchen sink                                    |      4 |               34165 | southhaven® 33 '' x 22 '' double basin sink kitchen sink                             |       0 | 0.433333 | 0.0493158 |
# | 4711 |        485 | pedistole sink                           |               2272 |     201396 | Partial       |             1 |            5 |         2272 | single bowl 33 '' l x 22 '' w farmhouse/apron kitchen sink                                     |      5 |               26706 | rectangular undermount bathroom sink with overflow                                   |       0 | 0.433333 | 0.0493158 |
# | 4712 |        485 | pedistole sink                           |               2273 |     201630 | Partial       |             1 |            6 |         2273 | retrofit 27 '' l x 22 '' w farmhouse/apron kitchen sink                                        |      6 |               26699 | tempered glass circular vessel bathroom sink                                         |       0 | 0.433333 | 0.0493158 |
# | 4713 |        485 | pedistole sink                           |               2274 |     201536 | Partial       |             1 |            7 |         2274 | retrofit 30 '' l x 22 '' w farmhouse/apron kitchen sink                                        |      7 |               22196 | whitehaven 36 '' x 14.75 '' sink grid                                                |       0 | 0.433333 | 0.0493158 |
# | 4714 |        485 | pedistole sink                           |               2275 |     201634 | Partial       |             1 |            8 |         2275 | retrofit 33 '' l x 22 '' w farmhouse/apron kitchen sink                                        |      8 |               37232 | sinkin plastic sink dish rack                                                        |       0 | 0.433333 | 0.0493158 |
# | 4715 |        485 | pedistole sink                           |               3795 |     201624 | Partial       |             1 |            9 |         3795 | nepal 33 '' l x 19 '' w farmhouse/apron kitchen sink with sink grid and strainer               |      9 |                3792 | forster metal oval undermount bathroom sink                                          |       0 | 0.433333 | 0.0493158 |
# | 4716 |        485 | pedistole sink                           |               3796 |     201537 | Partial       |             1 |           10 |         3796 | apollo 36 '' l x 19 '' w farmhouse/apron kitchen sink with sink grid and strainer              |     10 |               19763 | 60 '' double sink bathroom vanity set                                                |       1 | 0.433333 | 0.0493158 |

# %%
side_by_side
# Out:
#       query_id        query  ideal_product_id  ideal_id ideal_label  \
# 0            0  salon chair              1197        99       Exact
# 1            0  salon chair              1198       116       Exact
# 2            0  salon chair              2636         3       Exact
# 3            0  salon chair              2638        66       Exact
# 4            0  salon chair              5936        10       Exact
# ...        ...          ...               ...       ...         ...
# 4732       487   rack glass               110    202050     Partial
# 4733       487   rack glass               285    202336     Partial
# 4734       487   rack glass               573    202462     Partial
# 4735       487   rack glass               635    202178     Partial
# 4736       487   rack glass               660    202351     Partial
#
#       ideal_grade  ideal_rank  product_id  \
# 0             2.0           1        1197
# 1             2.0           2        1198
# 2             2.0           3        2636
# 3             2.0           4        2638
# 4             2.0           5        5936
# ...           ...         ...         ...
# 4732          1.0           6         110
# 4733          1.0           7         285
# 4734          1.0           8         573
# 4735          1.0           9         635
# 4736          1.0          10         660
#
#                                      ideal_product_name  rank  \
# 0     lizzy 25.6 '' w bariatric antimicrobial waitin...     1
# 1     rackham 26.8 '' w bariatric antimicrobial pvc ...     2
# 2     25 '' wide faux leather manual swivel standard...     3
# 3                            faux leather massage chair     4
# 4     69 '' w metal seat waiting room chair with met...     5
# ...                                                 ...   ...
# 4732                 west harptree 34 '' w garment rack     6
# 4733                       3 shelf movable storage rack     7
# 4734                    5 - hook freestanding coat rack     8
# 4735                    4 - hook freestanding coat rack     9
# 4736                  strine shoe clothing storage rack    10
#
#       product_id_actual                                product_name_actual  \
# 0                  7465                                   hair salon chair
# 1                  7468  mercer41 hair salon chair hydraulic styling ch...
# 2                 25431                      barberpub salon massage chair
# 3                 25432  barberpub hydraulic salon spa reclining massag...
# 4                 15612                                      massage chair
# ...                 ...                                                ...
# 4732              40243                    madisen hanging wine glass rack
# 4733              40244                       kena hanging wine glass rack
# 4734              39976                       wall mounted wine glass rack
# 4735              40247                       winn hanging wine glass rack
# 4736              40245                   podgorni hanging wine glass rack
#
#       grade       dcg      ndcg
# 0       2.0  8.536905  0.971549
# 1       2.0  8.536905  0.971549
# 2       2.0  8.536905  0.971549
# 3       2.0  8.536905  0.971549
# 4       2.0  8.536905  0.971549
# ...     ...       ...       ...
# 4732    0.0  0.000000  0.000000
# 4733    0.0  0.000000  0.000000
# 4734    0.0  0.000000  0.000000
# 4735    0.0  0.000000  0.000000
# 4736    0.0  0.000000  0.000000
#
# [4737 rows x 15 columns]
