# %% [markdown]
# ## Lesson 1 - Can we just generate blind synonyms?
#
# In this lesson we work on generating blind synonyms using LLMs. This is often the first stop for search teams.
#
# To run:
# * Either make sure Ollama is running or you have an `OPENAI_API_KEY` installed

# %%
from cheat_at_search.wands_data import products, queries
from cheat_at_search.strategy import (
    BM25Search,
    MiniLMSearch,
    EnrichedBM25Search,
    EnrichedJustRoomBM25Search,
    SynonymSearch,
)

bm25 = BM25Search(products)
synonym = SynonymSearch(products)
# Out:
# 2025-05-28 11:10:09,292 - cheat_at_search.wands_data - INFO - Directory /Users/doug/ws/cheat-with-llms/notebooks/data/wands already exists. Skipping clone.
# 2025-05-28 11:10:09,293 - cheat_at_search.wands_data - INFO - Loading relevance labels from /Users/doug/ws/cheat-with-llms/notebooks/data/wands/dataset/label.csv
# 2025-05-28 11:10:09,356 - cheat_at_search.wands_data - INFO - Loaded 231873 relevance labels
# 2025-05-28 11:10:09,356 - cheat_at_search.wands_data - INFO - Directory /Users/doug/ws/cheat-with-llms/notebooks/data/wands already exists. Skipping clone.
# 2025-05-28 11:10:09,356 - cheat_at_search.wands_data - INFO - Loading queries from /Users/doug/ws/cheat-with-llms/notebooks/data/wands/dataset/query.csv
# 2025-05-28 11:10:09,357 - cheat_at_search.wands_data - INFO - Loaded 480 queries
# 2025-05-28 11:10:09,358 - cheat_at_search.wands_data - INFO - Directory /Users/doug/ws/cheat-with-llms/notebooks/data/wands already exists. Skipping clone.
# 2025-05-28 11:10:09,358 - cheat_at_search.wands_data - INFO - Loading products from /Users/doug/ws/cheat-with-llms/notebooks/data/wands/dataset/product.csv
# 2025-05-28 11:10:09,739 - cheat_at_search.wands_data - INFO - Loaded 42994 products
# /Users/doug/ws/cheat-with-llms/cheat_at_search/wands_data.py:83: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['product_description'].fillna('', inplace=True)
# /Users/doug/ws/cheat-with-llms/cheat_at_search/wands_data.py:84: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['product_name'].fillna('', inplace=True)
# 2025-05-28 11:10:12,362 - searcharray.indexing - INFO - Indexing begins w/ 4 workers
# 2025-05-28 11:10:12,364 - searcharray.indexing - INFO - 0 Batch Start tokenization
# 2025-05-28 11:10:12,364 - searcharray.indexing - INFO - Tokenizing 42994 documents
# 2025-05-28 11:10:12,470 - searcharray.indexing - INFO - Tokenized 10000 (23.259059403637718%)
# 2025-05-28 11:10:12,570 - searcharray.indexing - INFO - Tokenized 20000 (46.518118807275435%)
# 2025-05-28 11:10:12,663 - searcharray.indexing - INFO - Tokenized 30000 (69.77717821091315%)
# 2025-05-28 11:10:12,754 - searcharray.indexing - INFO - Tokenized 40000 (93.03623761455087%)
# 2025-05-28 11:10:12,798 - searcharray.indexing - INFO - Tokenization -- vstacking
# 2025-05-28 11:10:12,799 - searcharray.indexing - INFO - Tokenization -- DONE
# 2025-05-28 11:10:12,801 - searcharray.indexing - INFO - Inverting docs->terms
# 2025-05-28 11:10:12,819 - searcharray.indexing - INFO - Encoding positions to bit array
# 2025-05-28 11:10:12,832 - searcharray.indexing - INFO - Batch tokenization complete
# 2025-05-28 11:10:12,832 - searcharray.indexing - INFO - (main thread) Processing 1 batch results
# 2025-05-28 11:10:12,842 - searcharray.indexing - INFO - Indexing from tokenization complete
# 2025-05-28 11:10:12,849 - searcharray.indexing - INFO - Indexing begins w/ 4 workers
# 2025-05-28 11:10:12,851 - searcharray.indexing - INFO - 0 Batch Start tokenization
# 2025-05-28 11:10:12,851 - searcharray.indexing - INFO - Tokenizing 42994 documents
# 2025-05-28 11:10:13,194 - searcharray.indexing - INFO - Tokenized 10000 (23.259059403637718%)
# 2025-05-28 11:10:13,544 - searcharray.indexing - INFO - Tokenized 20000 (46.518118807275435%)
# 2025-05-28 11:10:13,910 - searcharray.indexing - INFO - Tokenized 30000 (69.77717821091315%)
# 2025-05-28 11:10:14,296 - searcharray.indexing - INFO - Tokenized 40000 (93.03623761455087%)
# 2025-05-28 11:10:14,438 - searcharray.indexing - INFO - Tokenization -- vstacking
# 2025-05-28 11:10:14,443 - searcharray.indexing - INFO - Tokenization -- DONE
# 2025-05-28 11:10:14,451 - searcharray.indexing - INFO - Inverting docs->terms
# 2025-05-28 11:10:14,723 - searcharray.indexing - INFO - Encoding positions to bit array
# 2025-05-28 11:10:14,777 - searcharray.indexing - INFO - Batch tokenization complete
# 2025-05-28 11:10:14,778 - searcharray.indexing - INFO - (main thread) Processing 1 batch results
# 2025-05-28 11:10:14,834 - searcharray.indexing - INFO - Indexing from tokenization complete
# 2025-05-28 11:10:14,866 - searcharray.indexing - INFO - Indexing begins w/ 4 workers
# 2025-05-28 11:10:14,868 - searcharray.indexing - INFO - 0 Batch Start tokenization
# 2025-05-28 11:10:14,868 - searcharray.indexing - INFO - Tokenizing 42994 documents
# 2025-05-28 11:10:14,968 - searcharray.indexing - INFO - Tokenized 10000 (23.259059403637718%)
# 2025-05-28 11:10:15,063 - searcharray.indexing - INFO - Tokenized 20000 (46.518118807275435%)
# 2025-05-28 11:10:15,155 - searcharray.indexing - INFO - Tokenized 30000 (69.77717821091315%)
# 2025-05-28 11:10:15,244 - searcharray.indexing - INFO - Tokenized 40000 (93.03623761455087%)
# 2025-05-28 11:10:15,291 - searcharray.indexing - INFO - Tokenization -- vstacking
# 2025-05-28 11:10:15,292 - searcharray.indexing - INFO - Tokenization -- DONE
# 2025-05-28 11:10:15,294 - searcharray.indexing - INFO - Inverting docs->terms
# 2025-05-28 11:10:15,311 - searcharray.indexing - INFO - Encoding positions to bit array
# 2025-05-28 11:10:15,324 - searcharray.indexing - INFO - Batch tokenization complete
# 2025-05-28 11:10:15,324 - searcharray.indexing - INFO - (main thread) Processing 1 batch results
# 2025-05-28 11:10:15,334 - searcharray.indexing - INFO - Indexing from tokenization complete
# 2025-05-28 11:10:15,343 - searcharray.indexing - INFO - Indexing begins w/ 4 workers
# 2025-05-28 11:10:15,345 - searcharray.indexing - INFO - 0 Batch Start tokenization
# 2025-05-28 11:10:15,345 - searcharray.indexing - INFO - Tokenizing 42994 documents
# 2025-05-28 11:10:15,687 - searcharray.indexing - INFO - Tokenized 10000 (23.259059403637718%)
# 2025-05-28 11:10:16,006 - searcharray.indexing - INFO - Tokenized 20000 (46.518118807275435%)
# 2025-05-28 11:10:16,362 - searcharray.indexing - INFO - Tokenized 30000 (69.77717821091315%)
# 2025-05-28 11:10:16,731 - searcharray.indexing - INFO - Tokenized 40000 (93.03623761455087%)
# 2025-05-28 11:10:16,887 - searcharray.indexing - INFO - Tokenization -- vstacking
# 2025-05-28 11:10:16,892 - searcharray.indexing - INFO - Tokenization -- DONE
# 2025-05-28 11:10:16,899 - searcharray.indexing - INFO - Inverting docs->terms
# 2025-05-28 11:10:17,163 - searcharray.indexing - INFO - Encoding positions to bit array
# 2025-05-28 11:10:17,210 - searcharray.indexing - INFO - Batch tokenization complete
# 2025-05-28 11:10:17,211 - searcharray.indexing - INFO - (main thread) Processing 1 batch results
# 2025-05-28 11:10:17,266 - searcharray.indexing - INFO - Indexing from tokenization complete

# %% [markdown]
# ### Ideal top 10 for each query

# %%
from cheat_at_search.wands_data import labeled_queries

def ideal10():
    
    ideal_results = labeled_queries.sort_values(['query_id', 'grade'], ascending=(True, False))
    ideal_results['rank'] = ideal_results.groupby('query_id').cumcount() + 1
    ideal_top_10 = ideal_results[ideal_results['rank'] <= 10] \
        .add_prefix('ideal_') \
        .rename(columns={'ideal_query_id': 'query_id', 'ideal_query': 'query'})
    
    ideal_top_10 = ideal_top_10.merge(
        products[['product_id', 'product_name']], how='left', left_on='ideal_product_id', right_on='product_id'
    ).rename(columns={'product_name': 'ideal_product_name'}).drop(columns='ideal_query_class')
    
    return ideal_top_10

ideal_top_10 = ideal10()
ideal_top_10
# Out:
#       query_id        query  ideal_product_id  ideal_id ideal_label  \
# 0            0  salon chair              1197        99       Exact
# 1            0  salon chair              1198       116       Exact
# 2            0  salon chair              2636         3       Exact
# 3            0  salon chair              2638        66       Exact
# 4            0  salon chair              5936        10       Exact
# ...        ...          ...               ...       ...         ...
# 4732       487   rack glass               110    202050     Partial
# 4733       487   rack glass               285    202336     Partial
# 4734       487   rack glass               573    202462     Partial
# 4735       487   rack glass               635    202178     Partial
# 4736       487   rack glass               660    202351     Partial
#
#       ideal_grade  ideal_rank  product_id  \
# 0             2.0           1        1197
# 1             2.0           2        1198
# 2             2.0           3        2636
# 3             2.0           4        2638
# 4             2.0           5        5936
# ...           ...         ...         ...
# 4732          1.0           6         110
# 4733          1.0           7         285
# 4734          1.0           8         573
# 4735          1.0           9         635
# 4736          1.0          10         660
#
#                                      ideal_product_name
# 0     lizzy 25.6 '' w bariatric antimicrobial waitin...
# 1     rackham 26.8 '' w bariatric antimicrobial pvc ...
# 2     25 '' wide faux leather manual swivel standard...
# 3                            faux leather massage chair
# 4     69 '' w metal seat waiting room chair with met...
# ...                                                 ...
# 4732                 west harptree 34 '' w garment rack
# 4733                       3 shelf movable storage rack
# 4734                    5 - hook freestanding coat rack
# 4735                    4 - hook freestanding coat rack
# 4736                  strine shoe clothing storage rack
#
# [4737 rows x 9 columns]

# %% [markdown]
# ## Run a simple BM25 search, evaluate
#
# * Simple BM25 search, `/cheat_at_search/strategies/bm25.py`

# %%
from cheat_at_search.eval import grade_results

def run_strategy(strategy):
    
    results = strategy.search_all(queries)
    graded = grade_results(
        results,
        max_grade=2,
        k=10,
    )
    
    idcg = graded['idcg'].iloc[0]
    dcgs = graded.groupby(["query", 'query_id'])["discounted_gain"].sum().sort_values(ascending=False).rename('dcg')
    ndcgs = dcgs / idcg
    ndcgs = ndcgs.rename('ndcg')
    
    graded = graded.merge(dcgs, on=['query', 'query_id'])
    graded = graded.merge(ndcgs, on=['query', 'query_id'])
    
    return graded

graded_bm25 = run_strategy(bm25)
graded_bm25
# Out:
# /Users/doug/ws/cheat-with-llms/cheat_at_search/eval.py:18: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   graded_results['grade'].fillna(0, inplace=True)
#       product_id                                       product_name  \
# 0           7465                                   hair salon chair
# 1           7468  mercer41 hair salon chair hydraulic styling ch...
# 2          25431                      barberpub salon massage chair
# 3          25432  barberpub hydraulic salon spa reclining massag...
# 4          15612                                      massage chair
# ...          ...                                                ...
# 4795       40243                    madisen hanging wine glass rack
# 4796       40244                       kena hanging wine glass rack
# 4797       39976                       wall mounted wine glass rack
# 4798       40247                       winn hanging wine glass rack
# 4799       40245                   podgorni hanging wine glass rack
#
#                  product_class  \
# 0     Massage Chairs|Recliners
# 1               Massage Chairs
# 2               Massage Chairs
# 3     Massage Chairs|Recliners
# 4               Massage Chairs
# ...                        ...
# 4795                Wine Racks
# 4796                Wine Racks
# 4797                Wine Racks
# 4798                Wine Racks
# 4799                Wine Racks
#
#                                      category hierarchy  \
# 0     Furniture / Living Room Furniture / Chairs & S...
# 1     Furniture / Living Room Furniture / Chairs & S...
# 2     Furniture / Living Room Furniture / Chairs & S...
# 3     Furniture / Living Room Furniture / Chairs & S...
# 4     Furniture / Living Room Furniture / Chairs & S...
# ...                                                 ...
# 4795  Kitchen & Tabletop / Tableware & Drinkware / B...
# 4796  Kitchen & Tabletop / Tableware & Drinkware / B...
# 4797  Kitchen & Tabletop / Tableware & Drinkware / B...
# 4798  Kitchen & Tabletop / Tableware & Drinkware / B...
# 4799  Kitchen & Tabletop / Tableware & Drinkware / B...
#
#                                     product_description  \
# 0     offers a wide selection of professional salon ...
# 1     mercer41 beauty offers a wide selection profes...
# 2     salon chairs are a wonderful avenue for hairst...
# 3     salon chairs are a wonderful avenue for hairst...
# 4     features heavy duty steel frame . premium chro...
# ...                                                 ...
# 4795  complement your farmhouse kitchen decor with t...
# 4796  spruce up your farmhouse kitchen decor with th...
# 4797  the latest addition to this collection , this ...
# 4798  are you looking for a safe and decorative solu...
# 4799  display and protect your delicate wine or marg...
#
#                                        product_features  rating_count  \
# 0     fauxleathertype : pu|legheight-toptobottom:18|...          69.0
# 1     seatfillmaterial : foam|waterrepellant : no re...           1.0
# 2     supplierintendedandapproveduse : non residenti...           4.0
# 3     backheight-seattotopofback:15.7|recliningtyped...           5.0
# 4     overallheight-toptobottom:35.5|productcare : d...          59.0
# ...                                                 ...           ...
# 4795  producttype : wine glass rack|overallwidth-sid...          29.0
# 4796  warrantylength:1 year|producttype : wine glass...          23.0
# 4797  overallheight-toptobottom:4|design : wall moun...          34.0
# 4798  overallheight-toptobottom:1.5|overallwidth-sid...         305.0
# 4799  overallheight-toptobottom:1.5|stemwarecapacity...           6.0
#
#       average_rating  review_count  \
# 0                4.5          53.0
# 1                5.0           1.0
# 2                5.0           4.0
# 3                4.0           5.0
# 4                4.5          50.0
# ...              ...           ...
# 4795             5.0          20.0
# 4796             5.0          18.0
# 4797             4.5          18.0
# 4798             5.0         187.0
# 4799             4.0           6.0
#
#                                                features  ... query_id rank  \
# 0     [fauxleathertype : pu, legheight-toptobottom:1...  ...        0    1
# 1     [seatfillmaterial : foam, waterrepellant : no ...  ...        0    2
# 2     [supplierintendedandapproveduse : non resident...  ...        0    3
# 3     [backheight-seattotopofback:15.7, recliningtyp...  ...        0    4
# 4     [overallheight-toptobottom:35.5, productcare :...  ...        0    5
# ...                                                 ...  ...      ...  ...
# 4795  [producttype : wine glass rack, overallwidth-s...  ...      487    6
# 4796  [warrantylength:1 year, producttype : wine gla...  ...      487    7
# 4797  [overallheight-toptobottom:4, design : wall mo...  ...      487    8
# 4798  [overallheight-toptobottom:1.5, overallwidth-s...  ...      487    9
# 4799  [overallheight-toptobottom:1.5, stemwarecapaci...  ...      487   10
#
#          query_class     id  label  grade discounted_gain      idcg       dcg  \
# 0     Massage Chairs   80.0  Exact    2.0            3.00  8.786905  8.536905
# 1     Massage Chairs  104.0  Exact    2.0            1.50  8.786905  8.536905
# 2     Massage Chairs   29.0  Exact    2.0            1.00  8.786905  8.536905
# 3     Massage Chairs   28.0  Exact    2.0            0.75  8.786905  8.536905
# 4     Massage Chairs  101.0  Exact    2.0            0.60  8.786905  8.536905
# ...              ...    ...    ...    ...             ...       ...       ...
# 4795             NaN    NaN    NaN    0.0            0.00  8.786905  0.000000
# 4796             NaN    NaN    NaN    0.0            0.00  8.786905  0.000000
# 4797             NaN    NaN    NaN    0.0            0.00  8.786905  0.000000
# 4798             NaN    NaN    NaN    0.0            0.00  8.786905  0.000000
# 4799             NaN    NaN    NaN    0.0            0.00  8.786905  0.000000
#
#           ndcg
# 0     0.971549
# 1     0.971549
# 2     0.971549
# 3     0.971549
# 4     0.971549
# ...        ...
# 4795  0.000000
# 4796  0.000000
# 4797  0.000000
# 4798  0.000000
# 4799  0.000000
#
# [4800 rows x 24 columns]

# %%
def side_by_side(graded, ideal_top_10):
    
    graded_view = graded[['query_id', 'query', 'rank', 'product_id', 'product_name',  'grade', 'dcg', 'ndcg']].rename(
                          columns={'product_id': 'product_id_actual', 'product_name': 'product_name_actual'})
    
    sxs = ideal_top_10.merge(graded_view, 
                             how='left',
                             left_on=['query_id', 'query', 'ideal_rank'],
                             right_on=['query_id', 'query', 'rank'])
    return sxs


sxs_bm25 = side_by_side(graded_bm25, ideal_top_10)
sxs_bm25
# Out:
#       query_id        query  ideal_product_id  ideal_id ideal_label  \
# 0            0  salon chair              1197        99       Exact
# 1            0  salon chair              1198       116       Exact
# 2            0  salon chair              2636         3       Exact
# 3            0  salon chair              2638        66       Exact
# 4            0  salon chair              5936        10       Exact
# ...        ...          ...               ...       ...         ...
# 4732       487   rack glass               110    202050     Partial
# 4733       487   rack glass               285    202336     Partial
# 4734       487   rack glass               573    202462     Partial
# 4735       487   rack glass               635    202178     Partial
# 4736       487   rack glass               660    202351     Partial
#
#       ideal_grade  ideal_rank  product_id  \
# 0             2.0           1        1197
# 1             2.0           2        1198
# 2             2.0           3        2636
# 3             2.0           4        2638
# 4             2.0           5        5936
# ...           ...         ...         ...
# 4732          1.0           6         110
# 4733          1.0           7         285
# 4734          1.0           8         573
# 4735          1.0           9         635
# 4736          1.0          10         660
#
#                                      ideal_product_name  rank  \
# 0     lizzy 25.6 '' w bariatric antimicrobial waitin...     1
# 1     rackham 26.8 '' w bariatric antimicrobial pvc ...     2
# 2     25 '' wide faux leather manual swivel standard...     3
# 3                            faux leather massage chair     4
# 4     69 '' w metal seat waiting room chair with met...     5
# ...                                                 ...   ...
# 4732                 west harptree 34 '' w garment rack     6
# 4733                       3 shelf movable storage rack     7
# 4734                    5 - hook freestanding coat rack     8
# 4735                    4 - hook freestanding coat rack     9
# 4736                  strine shoe clothing storage rack    10
#
#       product_id_actual                                product_name_actual  \
# 0                  7465                                   hair salon chair
# 1                  7468  mercer41 hair salon chair hydraulic styling ch...
# 2                 25431                      barberpub salon massage chair
# 3                 25432  barberpub hydraulic salon spa reclining massag...
# 4                 15612                                      massage chair
# ...                 ...                                                ...
# 4732              40243                    madisen hanging wine glass rack
# 4733              40244                       kena hanging wine glass rack
# 4734              39976                       wall mounted wine glass rack
# 4735              40247                       winn hanging wine glass rack
# 4736              40245                   podgorni hanging wine glass rack
#
#       grade       dcg      ndcg
# 0       2.0  8.536905  0.971549
# 1       2.0  8.536905  0.971549
# 2       2.0  8.536905  0.971549
# 3       2.0  8.536905  0.971549
# 4       2.0  8.536905  0.971549
# ...     ...       ...       ...
# 4732    0.0  0.000000  0.000000
# 4733    0.0  0.000000  0.000000
# 4734    0.0  0.000000  0.000000
# 4735    0.0  0.000000  0.000000
# 4736    0.0  0.000000  0.000000
#
# [4737 rows x 15 columns]

# %%
sxs_bm25[sxs_bm25['query'] == 'ottoman bed queen']
# Out:
#       query_id              query  ideal_product_id  ideal_id ideal_label  \
# 3381       344  ottoman bed queen               545     37893     Partial
# 3382       344  ottoman bed queen               998     37883     Partial
# 3383       344  ottoman bed queen              1030     37836     Partial
# 3384       344  ottoman bed queen              1367     37901     Partial
# 3385       344  ottoman bed queen              1537     37873     Partial
# 3386       344  ottoman bed queen              1563     37894     Partial
# 3387       344  ottoman bed queen              1730     37910     Partial
# 3388       344  ottoman bed queen              1753     37854     Partial
# 3389       344  ottoman bed queen              1844     37889     Partial
# 3390       344  ottoman bed queen              1927     37864     Partial
#
#       ideal_grade  ideal_rank  product_id  \
# 3381          1.0           1         545
# 3382          1.0           2         998
# 3383          1.0           3        1030
# 3384          1.0           4        1367
# 3385          1.0           5        1537
# 3386          1.0           6        1563
# 3387          1.0           7        1730
# 3388          1.0           8        1753
# 3389          1.0           9        1844
# 3390          1.0          10        1927
#
#                                      ideal_product_name  rank  \
# 3381                            loggins storage ottoman     1
# 3382  karlsefni 37.5 '' wide tufted rectangle standa...     2
# 3383            48 '' tufted rectangle standard ottoman     3
# 3384        roft 50 '' tufted rectangle storage ottoman     4
# 3385       henninger 25 '' tufted round storage ottoman     5
# 3386  luper 41.75 '' wide tufted rectangle storage o...     6
# 3387                             tufted storage ottoman     7
# 3388  camden 28.5 '' wide square folding bed cocktai...     8
# 3389          lampkins 24 '' rectangle standard ottoman     9
# 3390  denali 51.18 '' wide faux leather rectangle st...    10
#
#       product_id_actual                           product_name_actual  grade  \
# 3381               2089                 elzadie queen four poster bed    0.0
# 3382              38301         sinead queen upholstered platform bed    0.0
# 3383              14834  abbot diamond queen upholstered standard bed    0.0
# 3384               7371     carrollton queen upholstered standard bed    0.0
# 3385              29090      lamberton queen upholstered platform bed    0.0
# 3386              17289                 masonville queen platform bed    0.0
# 3387              17219     bianaca queen low profile four poster bed    0.0
# 3388               6503       karmakar queen upholstered platform bed    0.0
# 3389              34268                   fabienne queen standard bed    0.0
# 3390              32412         louque queen upholstered platform bed    0.0
#
#       dcg  ndcg
# 3381  0.0   0.0
# 3382  0.0   0.0
# 3383  0.0   0.0
# 3384  0.0   0.0
# 3385  0.0   0.0
# 3386  0.0   0.0
# 3387  0.0   0.0
# 3388  0.0   0.0
# 3389  0.0   0.0
# 3390  0.0   0.0

# %% [markdown]
# ## Lets try a simple synonym search
#
# Lets inspect SynonymSearch in strategies to see what it does, then lets run it to compare.

# %%
graded_syn = run_strategy(synonym)
sxs_syn = side_by_side(graded_syn, ideal_top_10)
sxs_syn
# Out:
# /Users/doug/ws/cheat-with-llms/cheat_at_search/eval.py:18: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   graded_results['grade'].fillna(0, inplace=True)
#       query_id        query  ideal_product_id  ideal_id ideal_label  \
# 0            0  salon chair              1197        99       Exact
# 1            0  salon chair              1198       116       Exact
# 2            0  salon chair              2636         3       Exact
# 3            0  salon chair              2638        66       Exact
# 4            0  salon chair              5936        10       Exact
# ...        ...          ...               ...       ...         ...
# 4732       487   rack glass               110    202050     Partial
# 4733       487   rack glass               285    202336     Partial
# 4734       487   rack glass               573    202462     Partial
# 4735       487   rack glass               635    202178     Partial
# 4736       487   rack glass               660    202351     Partial
#
#       ideal_grade  ideal_rank  product_id  \
# 0             2.0           1        1197
# 1             2.0           2        1198
# 2             2.0           3        2636
# 3             2.0           4        2638
# 4             2.0           5        5936
# ...           ...         ...         ...
# 4732          1.0           6         110
# 4733          1.0           7         285
# 4734          1.0           8         573
# 4735          1.0           9         635
# 4736          1.0          10         660
#
#                                      ideal_product_name  rank  \
# 0     lizzy 25.6 '' w bariatric antimicrobial waitin...     1
# 1     rackham 26.8 '' w bariatric antimicrobial pvc ...     2
# 2     25 '' wide faux leather manual swivel standard...     3
# 3                            faux leather massage chair     4
# 4     69 '' w metal seat waiting room chair with met...     5
# ...                                                 ...   ...
# 4732                 west harptree 34 '' w garment rack     6
# 4733                       3 shelf movable storage rack     7
# 4734                    5 - hook freestanding coat rack     8
# 4735                    4 - hook freestanding coat rack     9
# 4736                  strine shoe clothing storage rack    10
#
#       product_id_actual                                product_name_actual  \
# 0                 36868  dockrey wall mount salon spa hair styling stat...
# 1                  7465                                   hair salon chair
# 2                  7468  mercer41 hair salon chair hydraulic styling ch...
# 3                 25431                      barberpub salon massage chair
# 4                 25432  barberpub hydraulic salon spa reclining massag...
# ...                 ...                                                ...
# 4732              39976                       wall mounted wine glass rack
# 4733              34600   croll 12 bottle floor wine bottle and glass rack
# 4734              40243                    madisen hanging wine glass rack
# 4735              40244                       kena hanging wine glass rack
# 4736              40245                   podgorni hanging wine glass rack
#
#       grade       dcg      ndcg
# 0       0.0  5.564683  0.633293
# 1       2.0  5.564683  0.633293
# 2       2.0  5.564683  0.633293
# 3       2.0  5.564683  0.633293
# 4       2.0  5.564683  0.633293
# ...     ...       ...       ...
# 4732    0.0  0.142857  0.016258
# 4733    1.0  0.142857  0.016258
# 4734    0.0  0.142857  0.016258
# 4735    0.0  0.142857  0.016258
# 4736    0.0  0.142857  0.016258
#
# [4737 rows x 15 columns]

# %%
ndcg_syn = graded_syn.groupby('query')['ndcg'].first().sort_values()
ndcg_bm25 = graded_bm25.groupby('query')['ndcg'].first().sort_values()
(ndcg_syn - ndcg_bm25).sort_values()
# Out:
# query
# chair pillow cushion      -1.000000
# dining room tables        -0.962065
# marble                    -0.923181
# cortez pillow             -0.886194
# amarillo                  -0.885246
#                              ...
# leather chair              0.366120
# floating bed               0.381565
# tye dye duvet cover        0.442217
# kitchen storage cabinet    0.463623
# drum picture               0.512126
# Name: ndcg, Length: 480, dtype: float64

# %%
sxs_syn[sxs_syn['query'] == 'chair pillow cushion']
# Out:
#       query_id                 query  ideal_product_id  ideal_id ideal_label  \
# 4604       473  chair pillow cushion               198     49537       Exact
# 4605       473  chair pillow cushion               200     58110       Exact
# 4606       473  chair pillow cushion               202     49525       Exact
# 4607       473  chair pillow cushion               570     49538       Exact
# 4608       473  chair pillow cushion               571     49540       Exact
# 4609       473  chair pillow cushion              1372     49524       Exact
# 4610       473  chair pillow cushion              1376     58105       Exact
# 4611       473  chair pillow cushion              1828     58124       Exact
# 4612       473  chair pillow cushion              1830    197746       Exact
# 4613       473  chair pillow cushion              1881     49571       Exact
#
#       ideal_grade  ideal_rank  product_id  \
# 4604          2.0           1         198
# 4605          2.0           2         200
# 4606          2.0           3         202
# 4607          2.0           4         570
# 4608          2.0           5         571
# 4609          2.0           6        1372
# 4610          2.0           7        1376
# 4611          2.0           8        1828
# 4612          2.0           9        1830
# 4613          2.0          10        1881
#
#                              ideal_product_name  rank  product_id_actual  \
# 4604                       indoor chair cushion     1              19968
# 4605                 chair outdoor seat cushion     2               5542
# 4606                  chair indoor seat cushion     3              10294
# 4607                indoor dining chair cushion     4              39975
# 4608               indoor rocking chair cushion     5               9648
# 4609                              chair cushion     6              27635
# 4610      rockhill indoor/outdoor chair cushion     7              20037
# 4611        indoor/outdoor dining chair cushion     8              20124
# 4612  solid indoor/outdoor lounge chair cushion     9               8692
# 4613    sarver indoor/outdoor seat/back cushion    10              20039
#
#                                     product_name_actual  grade  dcg  ndcg
# 4604  home office chair with ergonomic adjustable hi...    0.0  0.0   0.0
# 4605                                indoor seat cushion    0.0  0.0   0.0
# 4606                          deep outdoor seat cushion    0.0  0.0   0.0
# 4607                 ergonomic memory foam seat cushion    0.0  0.0   0.0
# 4608                               outdoor seat cushion    0.0  0.0   0.0
# 4609                         ergonomic gel seat cushion    0.0  0.0   0.0
# 4610      home office decor indoor/outdoor seat cushion    0.0  0.0   0.0
# 4611                        indoor/outdoor seat cushion    0.0  0.0   0.0
# 4612                patio d indoor/outdoor seat cushion    0.0  0.0   0.0
# 4613     home office use soft flax outdoor seat cushion    0.0  0.0   0.0

# %%
sxs_bm25[sxs_bm25['query'] == 'chair pillow cushion']
# Out:
#       query_id                 query  ideal_product_id  ideal_id ideal_label  \
# 4604       473  chair pillow cushion               198     49537       Exact
# 4605       473  chair pillow cushion               200     58110       Exact
# 4606       473  chair pillow cushion               202     49525       Exact
# 4607       473  chair pillow cushion               570     49538       Exact
# 4608       473  chair pillow cushion               571     49540       Exact
# 4609       473  chair pillow cushion              1372     49524       Exact
# 4610       473  chair pillow cushion              1376     58105       Exact
# 4611       473  chair pillow cushion              1828     58124       Exact
# 4612       473  chair pillow cushion              1830    197746       Exact
# 4613       473  chair pillow cushion              1881     49571       Exact
#
#       ideal_grade  ideal_rank  product_id  \
# 4604          2.0           1         198
# 4605          2.0           2         200
# 4606          2.0           3         202
# 4607          2.0           4         570
# 4608          2.0           5         571
# 4609          2.0           6        1372
# 4610          2.0           7        1376
# 4611          2.0           8        1828
# 4612          2.0           9        1830
# 4613          2.0          10        1881
#
#                              ideal_product_name  rank  product_id_actual  \
# 4604                       indoor chair cushion     1              30279
# 4605                 chair outdoor seat cushion     2              37578
# 4606                  chair indoor seat cushion     3               7167
# 4607                indoor dining chair cushion     4              31137
# 4608               indoor rocking chair cushion     5                198
# 4609                              chair cushion     6               9636
# 4610      rockhill indoor/outdoor chair cushion     7               3472
# 4611        indoor/outdoor dining chair cushion     8                202
# 4612  solid indoor/outdoor lounge chair cushion     9                200
# 4613    sarver indoor/outdoor seat/back cushion    10               9630
#
#                                     product_name_actual  grade       dcg  ndcg
# 4604   replacement pillows outdoor lounge chair cushion    2.0  8.786905   1.0
# 4605  indoor/outdoor dining chair cushion and pillow...    2.0  8.786905   1.0
# 4606                   abbottsmoor dining chair cushion    2.0  8.786905   1.0
# 4607                     zipparoll indoor chair cushion    2.0  8.786905   1.0
# 4608                               indoor chair cushion    2.0  8.786905   1.0
# 4609              tropical outdoor lounge chair cushion    2.0  8.786905   1.0
# 4610                                  chair pad cushion    2.0  8.786905   1.0
# 4611                          chair indoor seat cushion    2.0  8.786905   1.0
# 4612                         chair outdoor seat cushion    2.0  8.786905   1.0
# 4613                   outdoor adirondack chair cushion    2.0  8.786905   1.0

# %%
synonym._synonyms('chair pillow cushion')
# Out:
# QueryWithSynonyms(keywords="[['chair', 'pillow', 'cushion']]", synonyms=[SynonymMapping(phrase='chair', synonyms=['office chair', 'stool', 'seating', 'sofa']), SynonymMapping(phrase='pillow', synonyms=['headrest', 'neck support', 'backrest', 'body pillow']), SynonymMapping(phrase='cushion', synonyms=['padded seat cover', 'seat cushion', 'armrest cushion', 'footrest'])])

# %%
synonym._synonyms('drum picture')
# Out:
# QueryWithSynonyms(keywords='drum picture', synonyms=[SynonymMapping(phrase='drum photo', synonyms=['drum image', 'drum artwork', 'drum photography']), SynonymMapping(phrase='guitar picture', synonyms=['guitar photo', 'guitar image', 'guitar photography']), SynonymMapping(phrase='music instrument picture', synonyms=['musical instrument', 'instrumentation', 'equipment']), SynonymMapping(phrase='wall art drum', synonyms=['drum wall decor', 'drum wall hanging', 'drum print'])])

# %%
sxs_bm25[sxs_bm25['query'] == 'drum picture']
# Out:
#       query_id         query  ideal_product_id  ideal_id ideal_label  \
# 1470       147  drum picture              6243     21573       Exact
# 1471       147  drum picture              6741     21596       Exact
# 1472       147  drum picture              6742     21595       Exact
# 1473       147  drum picture             11793     21584       Exact
# 1474       147  drum picture             12093     21562       Exact
# 1475       147  drum picture             12159     21633       Exact
# 1476       147  drum picture             12186     21616       Exact
# 1477       147  drum picture             13874     21640       Exact
# 1478       147  drum picture             15777     21587       Exact
# 1479       147  drum picture             29890     21588       Exact
#
#       ideal_grade  ideal_rank  product_id  \
# 1470          2.0           1        6243
# 1471          2.0           2        6741
# 1472          2.0           3        6742
# 1473          2.0           4       11793
# 1474          2.0           5       12093
# 1475          2.0           6       12159
# 1476          2.0           7       12186
# 1477          2.0           8       13874
# 1478          2.0           9       15777
# 1479          2.0          10       29890
#
#                                      ideal_product_name  rank  \
# 1470  bourbon street blues iv by robert brasher - pi...     1
# 1471          green drums graphic art on wrapped canvas     2
# 1472                  green drums graphic art on plaque     3
# 1473                              dog drumming painting     4
# 1474  2 piece drums picture of a drum kit percussion...     5
# 1475                  snare drum - wrapped canvas print     6
# 1476  multi-color drums on music sheet # 2 - graphic...     7
# 1477  the medicine drum by carl and grace moon photo...     8
# 1478      drummer boy - picture frame textual art print     9
# 1479         drummers drumming by cathy walters - print    10
#
#       product_id_actual                            product_name_actual  grade  \
# 1470              15321                 lavada 4-light drum chandelier    0.0
# 1471              13904                 jurgens mahogany picture frame    0.0
# 1472              29189                         satrogan picture frame    0.0
# 1473              27494                    gemmill matte picture frame    0.0
# 1474              39625                           design picture frame    0.0
# 1475              34840                 elysium elephant picture frame    0.0
# 1476              24581  denise 5 - light candle style drum chandelier    0.0
# 1477              29202                  choe watercolor picture frame    0.0
# 1478              16215                           single picture frame    0.0
# 1479               2428       ncaa university of alabama picture frame    0.0
#
#       dcg  ndcg
# 1470  0.0   0.0
# 1471  0.0   0.0
# 1472  0.0   0.0
# 1473  0.0   0.0
# 1474  0.0   0.0
# 1475  0.0   0.0
# 1476  0.0   0.0
# 1477  0.0   0.0
# 1478  0.0   0.0
# 1479  0.0   0.0

# %%
sxs_syn[sxs_syn['query'] == 'drum picture']
# Out:
#       query_id         query  ideal_product_id  ideal_id ideal_label  \
# 1470       147  drum picture              6243     21573       Exact
# 1471       147  drum picture              6741     21596       Exact
# 1472       147  drum picture              6742     21595       Exact
# 1473       147  drum picture             11793     21584       Exact
# 1474       147  drum picture             12093     21562       Exact
# 1475       147  drum picture             12159     21633       Exact
# 1476       147  drum picture             12186     21616       Exact
# 1477       147  drum picture             13874     21640       Exact
# 1478       147  drum picture             15777     21587       Exact
# 1479       147  drum picture             29890     21588       Exact
#
#       ideal_grade  ideal_rank  product_id  \
# 1470          2.0           1        6243
# 1471          2.0           2        6741
# 1472          2.0           3        6742
# 1473          2.0           4       11793
# 1474          2.0           5       12093
# 1475          2.0           6       12159
# 1476          2.0           7       12186
# 1477          2.0           8       13874
# 1478          2.0           9       15777
# 1479          2.0          10       29890
#
#                                      ideal_product_name  rank  \
# 1470  bourbon street blues iv by robert brasher - pi...     1
# 1471          green drums graphic art on wrapped canvas     2
# 1472                  green drums graphic art on plaque     3
# 1473                              dog drumming painting     4
# 1474  2 piece drums picture of a drum kit percussion...     5
# 1475                  snare drum - wrapped canvas print     6
# 1476  multi-color drums on music sheet # 2 - graphic...     7
# 1477  the medicine drum by carl and grace moon photo...     8
# 1478      drummer boy - picture frame textual art print     9
# 1479         drummers drumming by cathy walters - print    10
#
#       product_id_actual                                product_name_actual  \
# 1470              37178                       percussion instruments chart
# 1471              12093  2 piece drums picture of a drum kit percussion...
# 1472              15321                     lavada 4-light drum chandelier
# 1473              13904                     jurgens mahogany picture frame
# 1474              29189                             satrogan picture frame
# 1475              27494                        gemmill matte picture frame
# 1476              39625                               design picture frame
# 1477              34840                     elysium elephant picture frame
# 1478              24581      denise 5 - light candle style drum chandelier
# 1479              29202                      choe watercolor picture frame
#
#       grade  dcg      ndcg
# 1470    2.0  4.5  0.512126
# 1471    2.0  4.5  0.512126
# 1472    0.0  4.5  0.512126
# 1473    0.0  4.5  0.512126
# 1474    0.0  4.5  0.512126
# 1475    0.0  4.5  0.512126
# 1476    0.0  4.5  0.512126
# 1477    0.0  4.5  0.512126
# 1478    0.0  4.5  0.512126
# 1479    0.0  4.5  0.512126
